# %% [markdown]
# **Generación de Notificaciones Falsas**

# %% [markdown]
# Para generar las direcciones aleatorias, usaremos archivos de acceso libre del Correo Uruguayo, disponible en https://catalogodatos.gub.uy/dataset/ide-direcciones-geograficas-del-uruguay
# Concatenamos todos los archivos en un único archivo csv. Eso permite que las direcciones sean geolocalizables y tengan sentido. De hecho, el archivo contiene las coordenadas de latitud y longitud de cada dirección. Al generar cada notificación, se eligirá una dirección al azar del archivo.

# %%
import pandas as pd
import os

# Lista de archivos CSV
archivos_csv = [
    'artigas.csv', 'canelones.csv', 'cerrolargo.csv', 'colonia.csv', 'durazno.csv',
    'flores.csv', 'florida.csv', 'lavalleja.csv', 'maldonado.csv', 'montevideo.csv',
    'paysandu.csv', 'rionegro.csv', 'rivera.csv', 'rocha.csv', 'salto.csv',
    'sanjose.csv', 'soriano.csv', 'tacuarembo.csv', 'treintaytres.csv'
]

# Leer y concatenar los archivos sin duplicar los títulos, usando low_memory=False
dataframes = [pd.read_csv(archivo, low_memory=False) for archivo in archivos_csv]
df_unido = pd.concat(dataframes, ignore_index=True)

# Guardar el DataFrame resultante a un nuevo archivo CSV
df_unido.to_csv('direcciones_de_uruguay.csv', index=False)

# %%
display(df_unido)
# Out:
#            latitud   longitud  \
# 0       -30.393342 -56.466233
# 1       -30.399250 -56.458571
# 2       -30.396084 -56.462343
# 3       -30.393411 -56.466146
# 4       -30.393215 -56.465923
# ...            ...        ...
# 1486375 -33.408042 -54.608429
# 1486376 -32.909574 -54.249243
# 1486377 -32.952456 -53.517681
# 1486378 -32.877252 -53.607981
# 1486379 -32.868843 -53.613272
#
#                                                  punto_wkb  codigo_postal  \
# 0        0101000020D17F0000C3F5285CD9D22041000000C0F051...          55000
# 1        0101000020D17F00007B14AE4793D820411F85EB314C51...          55000
# 2        0101000020D17F000000000000C2D520419A999959A451...          55000
# 3        0101000020D17F0000A4703D0AEAD22041333333D3EE51...          55000
# 4        0101000020D17F00008FC2F52815D320419A999939F451...          55000
# ...                                                    ...            ...
# 1486375  0101000020D17F0000713D0A57C40B2641EC51B8DE3D09...          30300
# 1486376  0101000020D17F0000CDCCCCCC251C2741CDCCCC2C6D3E...          33000
# 1486377  0101000020D17F00009A999919B131294133333393CD37...          31100
# 1486378  0101000020D17F00009A999919CEF12841CDCCCC4C3840...          31100
# 1486379  0101000020D17F0000CDCCCC4C2BEE2841666666862541...          31100
#
#          codigo_via         nombre_via  num_puerta letra_puerta  km  manzana  \
# 0           27114.0      12 DE OCTUBRE         2.0          NaN NaN      NaN
# 1           27114.0      12 DE OCTUBRE         6.0          NaN NaN      NaN
# 2           27114.0      12 DE OCTUBRE         8.0          NaN NaN      NaN
# 3           27114.0      12 DE OCTUBRE        10.0          NaN NaN      NaN
# 4           27114.0      12 DE OCTUBRE        13.0          NaN NaN      NaN
# ...             ...                ...         ...          ...  ..      ...
# 1486375     39648.0  VECINAL A ZAPICAN      9001.0          NaN NaN      NaN
# 1486376     16431.0    VECINAL LEONCHO         1.0          NaN NaN      NaN
# 1486377     37782.0          ZAPATA L1      9000.0          NaN NaN      NaN
# 1486378     37763.0          ZAPATA L2      9000.0          NaN NaN      NaN
# 1486379     37763.0          ZAPATA L2      9001.0          NaN NaN      NaN
#
#          solar nombre_inmueble localidad  codigo_localidad    departamento
# 0          NaN             NaN   ARTIGAS             135.0         ARTIGAS
# 1          NaN             NaN   ARTIGAS             135.0         ARTIGAS
# 2          NaN             NaN   ARTIGAS             135.0         ARTIGAS
# 3          NaN             NaN   ARTIGAS             135.0         ARTIGAS
# 4          NaN             NaN   ARTIGAS             135.0         ARTIGAS
# ...        ...             ...       ...               ...             ...
# 1486375    NaN             NaN       NaN               NaN  TREINTA Y TRES
# 1486376    NaN             NaN       NaN               NaN  TREINTA Y TRES
# 1486377    NaN             NaN       NaN               NaN  TREINTA Y TRES
# 1486378    NaN             NaN       NaN               NaN  TREINTA Y TRES
# 1486379    NaN             NaN       NaN               NaN  TREINTA Y TRES
#
# [1486380 rows x 15 columns]

# %% [markdown]
# Ahora establecemos la lista de eventos notificables (solo elegimos unos pocos eventos como ejemplo de caso de uso) y la lista de prestadores de servicios médicos según el departamento.

# %%
# Listas para los eventos y prestadores
eventos = [
    "Dengue",
    "Leptospirosis",
    "Meningitis Viral",
    "Meningitis Bacteriana"]
prestadores_por_departamento = {
    'ARTIGAS': ["ASSE", "COMERI", "GREMEDA IAMPP"],
    'CANELONES': ["ASOCIACION ESPAÑOLA", "ASSE", "CAAMEPA IAMPP", "CASMU IAMPP", "CIRCULO CATOLICO", "COMECA IAMPP", "COSEM IAMPP", "CRAMI IAMPP", "CUDAM", "GREMCA", "HOSPITAL EVANGELICO", "MEDICA URUGUAYA", "SMI", "UNIVERSAL"],
    'CERRO LARGO': ["ASSE", "CAMCEL", "MEDICA URUGUAYA"],
    'COLONIA': ["ASSE", "CAMEC", "CAMOC IAMPP", "CIRCULO CATOLICO", "HOSPITAL EVANGELICO", "MEDICA URUGUAYA"],
    'DURAZNO': ["ASSE", "CAMEDUR IAMPP", "MEDICA URUGUAYA"],
    'FLORES': ["ASSE", "COMEFLO IAMPP"],
    'FLORIDA': ["ASSE", "CIRCULO CATOLICO", "COMEF IAMPP", "HOSPITAL EVANGELICO", "MEDICA URUGUAYA"],
    'LAVALLEJA': ["ASSE", "CAMDEL IAMPP", "IAC", "MEDICA URUGUAYA"],
    'MALDONADO': ["ASSE", "AMDM IAMPP", "ASOCIACION ESPAÑOLA", "BLUE CROSS", "CASMU IAMPP", "CIRCULO CATOLICO", "CRAME IAMPP", "MEDICA URUGUAYA"],
    'MONTEVIDEO': ["ASSE", "ASOCIACION ESPAÑOLA", "BLUE CROSS", "CASMU IAMPP", "CIRCULO CATOLICO", "COSEM IAMPP", "CUDAM", "GREMCA", "HOSPITAL BRITANICO", "HOSPITAL EVANGELICO", "MEDICARE", "MEDICA URUGUAYA", "MP", "SEGURO AMERICANO", "SMI", "SUMMUN", "UNIVERSAL"],
    'PAYSANDU': ["ASSE", "COMEPA"],
    'RIVERA': ["ASSE", "CASMER IAMPP", "COMERI", "MEDICA URUGUAYA"],
    'ROCHA': ["ASSE", "COMERO IAMPP", "MEDICA URUGUAYA"],
    'RIO NEGRO': ["ASSE", "AMEDRIN", "CAMY", "HOSPITAL EVANGELICO", "MEDICA URUGUAYA"],
    'SALTO': ["ASSE", "SMQS"],
    'SAN JOSE': ["ASSE", "AMSJ IAMPP", "ASOCIACION ESPAÑOLA", "CASMU IAMPP", "CIRCULO CATOLICO", "GREMCA", "HOSPITAL EVANGELICO", "MEDICA URUGUAYA"],
    'SORIANO': ["ASSE", "CAMS IAMPP", "CIRCULO CATOLICO", "HOSPITAL EVANGELICO", "MEDICA URUGUAYA"],
    'TACUAREMBO': ["ASSE", "COMTA IAMPP", "MEDICA URUGUAYA"],
    'TREINTA Y TRES': ["ASSE", "CAMCEL", "IAC", "MEDICA URUGUAYA"]
}

# %% [markdown]
# Generador de cédulas de identidad y características de teléfono por localidad

# %%
# URL de la API para generar cédulas
api_url = "https://ciuy-consumers-api.vercel.app/generate"

# Mapeo de números de teléfono por localidad/departamento

telefonos = {
    'CANELONES': '433x xxxx',
    'MALDONADO': '42xx xxxx',
    'ROCHA': '447x xxxx',
    'TREINTA y TRES': '445x xxxx',
    'CERRO LARGO': '464x xxxx',
    'RIVERA': '462x xxxx',
    'ARTIGAS': '477x xxxx',
    'SALTO': '473x xxxx',
    'PAYSANDU': '472x xxxx',
    'RIO NEGRO': '456x xxxx',
    'COLONIA': '452x xxxx',
    'SAN JOSE': '434x xxxx',
    'FLORES': '4364 xxxx',
    'FLORIDA': '435x xxxx',
    'LAVALLEJA': '444x xxxx',
    'DURAZNO': '436x xxxx',
    'SORIANO': '453x xxxx',
    'TACUAREMBO': '463x xxxx',
    'MONTEVIDEO': '2xxx xxxx'
}

# %% [markdown]
# Detalles adicionales según el evento

# %%
import random

def generar_informacion_adicional(evento):
    # Diccionario con la información adicional
    informacion_adicional = {
        'Dengue': {
            'Fiebre': ['S', 'N'],
            'Dolor abdominal intenso y continuo': ['S', 'N'],
            'Cefalea': ['S', 'N'],
            'Edemas': ['S', 'N'],
            'Dolor retroorbitario': ['S', 'N'],
            'Sangrado de Mucosas': ['S', 'N'],
            'Nauseas/Vómitos': ['S', 'N'],
            'Sangrado Grave': ['S', 'N'],
            'Exantema': ['S', 'N'],
            'Letargia o irritabilidad': ['S', 'N'],
            'Mialgias y/o artralgias': ['S', 'N'],
            'Shock': ['S', 'N'],
            'Hematocrito (%)': lambda: random.randint(20, 60),
            'Plaquetas (/mm3)': lambda: random.randint(30_000, 1_500_000),
            'Leucocitos sangre (/mm3)': lambda: random.randint(1_000, 40_000)
        },
        'Leptospirosis': {
            'Fiebre': ['S', 'N'],
            'Cefalea': ['S', 'N'],
            'Síndrome hemorragíparo': ['S', 'N'],
            'Mialgias y/o artralgias': ['S', 'N'],
            'Compromiso renal': ['S', 'N'],
            'Compromiso hepático': ['S', 'N'],
            'Sintomatología digestiva': ['S', 'N'],
            'Ictericia': ['S', 'N'],
            'Hiperemia conjuntival': ['S', 'N'],
            'Neumonia/Neumonitis': ['S', 'N'],
            'Lesiones de piel': ['S', 'N'],
            'Hematocrito (%)': lambda: random.randint(20, 60),
            'Plaquetas (/mm3)': lambda: random.randint(30_000, 1_500_000),
            'Leucocitos sangre (/mm3)': lambda: random.randint(1_000, 40_000),
            'Función hepática BT (mg/dl)': lambda: round(random.uniform(0.1, 12.0), 1),
            'Función hepática TGO (UI/l)': lambda: round(random.uniform(10, 200), 1),
            'Función hepática LDH (mg/dl)': lambda: random.randint(140, 1500),
            'Función hepática TGP (UI/l)': lambda: random.randint(7, 200),
            'Función renal azoemia (mg/dl)': lambda: round(random.uniform(7, 100), 1),
            'Función renal creatinemia (mg/dl)': lambda: round(random.uniform(0.6, 10.0), 1)
        },
        'Meningitis Viral': {
            'Fiebre': ['S', 'N'],
            'Convulsión': ['S', 'N'],
            'Petequias': ['S', 'N'],
            'Signos de irritación meníngea': ['S', 'N'],
            'Alteración de conciencia': ['S', 'N'],
            'Hipopefusión periférica': ['S', 'N'],
            'Paciente Grave': ['S', 'N'],
            'Directo LCR': ['Cocos Gram positivos', 'Cocos Gram negativos', 'Bacilos Gram positivos', 'Bacilos Gram negativos', 'No se observan bacterias'],
            'Aspecto LCR (citoquímico)': ['turbio', 'transparente'],
            'Glucosa LCR (mg/dl)': lambda: round(random.uniform(0, 99), 1),
            'Proteínas en LCR (mg/dl)': lambda: round(random.uniform(15, 50), 1),
            'Leucocitos LCR (/mm3)': lambda: random.randint(0, 10000),
            'Predominio': ['PMN', 'Linfocitos']
        },
        'Meningitis Bacteriana': {
            'Fiebre': ['S', 'N'],
            'Convulsión': ['S', 'N'],
            'Petequias': ['S', 'N'],
            'Signos de irritación meníngea': ['S', 'N'],
            'Alteración de conciencia': ['S', 'N'],
            'Hipopefusión periférica': ['S', 'N'],
            'Paciente Grave': ['S', 'N'],
            'Directo LCR': ['Cocos Gram positivos', 'Cocos Gram negativos', 'Bacilos Gram positivos', 'Bacilos Gram negativos', 'No se observan bacterias'],
            'Aspecto LCR (citoquímico)': ['turbio', 'transparente'],
            'Glucosa LCR (mg/dl)': lambda: round(random.uniform(0, 99), 1),
            'Proteínas en LCR (mg/dl)': lambda: round(random.uniform(15, 50), 1),
            'Leucocitos LCR (/mm3)': lambda: random.randint(0, 10000),
            'Predominio': ['PMN', 'Linfocitos']
        }
    }
    
    # Verificar si el evento es válido
    if evento not in informacion_adicional:
        raise ValueError(f"Evento '{evento}' no reconocido.")
    
    # Obtener los datos para el evento especificado
    info_evento = informacion_adicional[evento]
    
    # Generar valores para cada campo
    resultado = {}
    for clave, valor in info_evento.items():
        if callable(valor):
            resultado[clave] = valor()
        else:
            resultado[clave] = random.choice(valor)
    
    return resultado

# %% [markdown]
# Genero las notificaciones aleatorias usando faker

# %%
import pandas as pd
import random
from faker import Faker
from datetime import datetime, timedelta
import requests
import json

# Inicializar Faker

fake = Faker('es_ES')  # Faker para generar nombres y apellidos en español

# Función para calcular la edad a partir de la fecha de nacimiento y la fecha de inicio de síntomas

def calcular_edad(fecha_nacimiento, fecha_inicio_sintomas):
    edad = fecha_inicio_sintomas.year - fecha_nacimiento.year - ((fecha_inicio_sintomas.month, fecha_inicio_sintomas.day) < (fecha_nacimiento.month, fecha_nacimiento.day))
    return edad

# Generar un número celular

def generar_numero_celular():
    return f"09{random.randint(1000000, 9999999)}"

# Generar cédula uruguaya usando la API

def get_random_ci():
    try:
        response = requests.get(api_url)
        response.raise_for_status()  # Lanza un error si la solicitud falla
        data = response.json()
        return data.get("ci", None)  # Obtén el CI del JSON
    except requests.RequestException as e:
        print(f"Error al realizar la solicitud: {e}")
        return None

# Función para generar un número de teléfono basado en el departamento

def generar_telefono(departamento):
    depto = departamento.upper()   # Normaliza el nombre del departamento
    formato = telefonos.get(depto, 'N/A')  # Busca el formato en el diccionario
    if formato == 'N/A':  # Si no hay formato para el departamento, devuelve 'N/A'
        return 'N/A'
    # Genera un número reemplazando las 'x' por números aleatorios
    telefono = ''.join(str(random.randint(0, 9)) if char == 'x' else char for char in formato)
    return telefono

# Cargar el DataFrame de direcciones

direcciones_df = pd.read_csv("direcciones.csv")

# Definir fechas para el rango

fecha_inicio = datetime(2024, 1, 1)
fecha_fin = datetime(2024, 8, 9)

# Elegir prestador

def seleccionar_prestador(departamento):
    depto = departamento.upper()  # Convertir el nombre del departamento a mayúsculas
    prestadores = prestadores_por_departamento.get(depto, [])
    return random.choice(prestadores) if prestadores else 'N/A'


# Generar datos ficticios

num_personas = 500  # Número de personas a generar
personas = []

for _ in range(num_personas):
    # Determinar el sexo al azar
    sexo = random.choice(['M', 'F'])
    
    # Generar nombre y apellido según el sexo
    nombre = fake.first_name_male() if sexo == 'M' else fake.first_name_female()
    apellido = fake.last_name()
    
    # Seleccionar una dirección al azar
    direccion = direcciones_df.sample().iloc[0]
    calle = direccion['nombre_via']
    numero = direccion['num_puerta']
    
    # Asegurarse de que 'numero' sea una cadena, y convertirlo si es necesario
    numero_str = str(numero) if not pd.isna(numero) else ''
    
    # Concatenar calle y número
    if pd.notna(calle) and calle.strip():
        if numero_str.strip():
            address = f"{calle} {numero_str}"
        else:
            address = calle
    else:
        address = ''
    
    localidad = direccion['localidad']
    departamento = direccion['departamento']
    latitud = direccion['latitud']
    longitud = direccion['longitud']
    
    # Obtener teléfono y prestador
    telefono = generar_telefono(departamento)
    prestador = seleccionar_prestador(departamento)
    
    # Generar fechas
    fecha_nacimiento = fake.date_of_birth(minimum_age=0, maximum_age=90)
    fecha_inicio_sintomas = fake.date_between_dates(date_start=fecha_inicio, date_end=fecha_fin)
    
    # Calcular edad
    edad = calcular_edad(fecha_nacimiento, fecha_inicio_sintomas)
    
    # Seleccionar evento
    evento = random.choice(eventos)
    
    # Generar información adicional
    informacion_adicional = generar_informacion_adicional(evento)
    
    internado=random.choice(['S', 'N'])
    
    if internado =='S':
        tipo_internado=random.choice(['CTI', 'CM'])
    else:
        tipo_internado='sin dato'
    
    # Crear el diccionario de la persona
    persona = {
        "nombre": nombre,
        "apellido": apellido,
        "direccion": address,
        "localidad": localidad,
        "departamento": departamento,
        "latitud": latitud,
        "longitud": longitud,
        "cedula": get_random_ci(),
        "fecha_nacimiento": fecha_nacimiento.strftime('%Y-%m-%d'),
        "fecha_inicio_sintomas": fecha_inicio_sintomas.strftime('%Y-%m-%d'),
        "edad": edad,
        "sexo": sexo,
        "evento": evento,
        "telefono": telefono,
        "celular": generar_numero_celular(),
        "prestador": prestador,
        "internado": internado,
        "tipo_internado": tipo_internado,
        **informacion_adicional  # Agregar información adicional según el evento
    }
    
    personas.append(persona)


# Guardar los datos como JSON
with open("notificaciones_ficticias.json", "w") as f:
    json.dump(personas, f, indent=4)

# %%
import json

# Imprimir en formato JSON con indentación
print(json.dumps(personas, indent=4, ensure_ascii=False))
# Out:
# [
#     {
#         "nombre": "Luis Miguel",
#         "apellido": "Guillén",
#         "direccion": "SARANDI 10.0",
#         "localidad": "SAN CARLOS",
#         "departamento": "MALDONADO",
#         "latitud": -34.7891206860802,
#         "longitud": -54.9127554562374,
#         "cedula": "87613478",
#         "fecha_nacimiento": "1957-09-14",
#         "fecha_inicio_sintomas": "2024-07-19",
#         "edad": 66,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "4211 5854",
#         "celular": "096987669",
#         "prestador": "MEDICA URUGUAYA",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Convulsión": "N",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "N",
#         "Directo LCR": "Bacilos Gram negativos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 46.9,
#         "Proteínas en LCR (mg/dl)": 37.4,
#         "Leucocitos LCR (/mm3)": 3876,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Natalia",
#         "apellido": "Escolano",
#         "direccion": "DULCINEA 2946.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8743195257036,
#         "longitud": -56.1651984435631,
#         "cedula": "92564989",
#         "fecha_nacimiento": "1947-10-08",
#         "fecha_inicio_sintomas": "2024-05-23",
#         "edad": 76,
#         "sexo": "F",
#         "evento": "Leptospirosis",
#         "telefono": "2311 3475",
#         "celular": "097690180",
#         "prestador": "HOSPITAL EVANGELICO",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "S",
#         "Cefalea": "S",
#         "Síndrome hemorragíparo": "S",
#         "Mialgias y/o artralgias": "N",
#         "Compromiso renal": "N",
#         "Compromiso hepático": "N",
#         "Sintomatología digestiva": "N",
#         "Ictericia": "S",
#         "Hiperemia conjuntival": "N",
#         "Neumonia/Neumonitis": "S",
#         "Lesiones de piel": "S",
#         "Hematocrito (%)": 60,
#         "Plaquetas (/mm3)": 423756,
#         "Leucocitos sangre (/mm3)": 2036,
#         "Función hepática BT (mg/dl)": 4.1,
#         "Función hepática TGO (UI/l)": 45.9,
#         "Función hepática LDH (mg/dl)": 1141,
#         "Función hepática TGP (UI/l)": 113,
#         "Función renal azoemia (mg/dl)": 98.9,
#         "Función renal creatinemia (mg/dl)": 7.6
#     },
#     {
#         "nombre": "Juan",
#         "apellido": "Lerma",
#         "direccion": "VECINAL  3 (BARRIO SUR) 13.0",
#         "localidad": "SAN CARLOS",
#         "departamento": "MALDONADO",
#         "latitud": -34.7998705252816,
#         "longitud": -54.9174658183494,
#         "cedula": "96642583",
#         "fecha_nacimiento": "1940-04-14",
#         "fecha_inicio_sintomas": "2024-01-04",
#         "edad": 83,
#         "sexo": "M",
#         "evento": "Leptospirosis",
#         "telefono": "4298 7345",
#         "celular": "095951208",
#         "prestador": "MEDICA URUGUAYA",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Cefalea": "N",
#         "Síndrome hemorragíparo": "S",
#         "Mialgias y/o artralgias": "S",
#         "Compromiso renal": "S",
#         "Compromiso hepático": "S",
#         "Sintomatología digestiva": "S",
#         "Ictericia": "S",
#         "Hiperemia conjuntival": "S",
#         "Neumonia/Neumonitis": "S",
#         "Lesiones de piel": "N",
#         "Hematocrito (%)": 42,
#         "Plaquetas (/mm3)": 922375,
#         "Leucocitos sangre (/mm3)": 29113,
#         "Función hepática BT (mg/dl)": 11.0,
#         "Función hepática TGO (UI/l)": 83.3,
#         "Función hepática LDH (mg/dl)": 900,
#         "Función hepática TGP (UI/l)": 16,
#         "Función renal azoemia (mg/dl)": 64.9,
#         "Función renal creatinemia (mg/dl)": 6.1
#     },
#     {
#         "nombre": "Eduardo",
#         "apellido": "Cánovas",
#         "direccion": "CAMINO MALDONADO 6015.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8366755865097,
#         "longitud": -56.1163037189611,
#         "cedula": "91061243",
#         "fecha_nacimiento": "2015-10-13",
#         "fecha_inicio_sintomas": "2024-01-02",
#         "edad": 8,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "2321 0318",
#         "celular": "091794900",
#         "prestador": "GREMCA",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Convulsión": "N",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 41.0,
#         "Proteínas en LCR (mg/dl)": 43.1,
#         "Leucocitos LCR (/mm3)": 3410,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Olegario",
#         "apellido": "Miranda",
#         "direccion": "LUCIO RODRIGUEZ 4827.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8641955021532,
#         "longitud": -56.2579164900683,
#         "cedula": "81587922",
#         "fecha_nacimiento": "1968-04-12",
#         "fecha_inicio_sintomas": "2024-02-25",
#         "edad": 55,
#         "sexo": "M",
#         "evento": "Leptospirosis",
#         "telefono": "2533 6039",
#         "celular": "097652058",
#         "prestador": "ASOCIACION ESPAÑOLA",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "N",
#         "Cefalea": "N",
#         "Síndrome hemorragíparo": "N",
#         "Mialgias y/o artralgias": "S",
#         "Compromiso renal": "S",
#         "Compromiso hepático": "S",
#         "Sintomatología digestiva": "S",
#         "Ictericia": "S",
#         "Hiperemia conjuntival": "S",
#         "Neumonia/Neumonitis": "N",
#         "Lesiones de piel": "N",
#         "Hematocrito (%)": 41,
#         "Plaquetas (/mm3)": 1061828,
#         "Leucocitos sangre (/mm3)": 31299,
#         "Función hepática BT (mg/dl)": 1.9,
#         "Función hepática TGO (UI/l)": 172.3,
#         "Función hepática LDH (mg/dl)": 384,
#         "Función hepática TGP (UI/l)": 19,
#         "Función renal azoemia (mg/dl)": 55.2,
#         "Función renal creatinemia (mg/dl)": 2.9
#     },
#     {
#         "nombre": "Pepito",
#         "apellido": "Malo",
#         "direccion": "5 2055.0",
#         "localidad": NaN,
#         "departamento": "TACUAREMBO",
#         "latitud": -32.7530992984027,
#         "longitud": -56.5165979943629,
#         "cedula": "11654303",
#         "fecha_nacimiento": "1985-11-11",
#         "fecha_inicio_sintomas": "2024-03-09",
#         "edad": 38,
#         "sexo": "M",
#         "evento": "Dengue",
#         "telefono": "4631 3051",
#         "celular": "092429096",
#         "prestador": "MEDICA URUGUAYA",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "S",
#         "Dolor abdominal intenso y continuo": "S",
#         "Cefalea": "N",
#         "Edemas": "S",
#         "Dolor retroorbitario": "N",
#         "Sangrado de Mucosas": "S",
#         "Nauseas/Vómitos": "S",
#         "Sangrado Grave": "S",
#         "Exantema": "N",
#         "Letargia o irritabilidad": "N",
#         "Mialgias y/o artralgias": "S",
#         "Shock": "S",
#         "Hematocrito (%)": 55,
#         "Plaquetas (/mm3)": 1114624,
#         "Leucocitos sangre (/mm3)": 37944
#     },
#     {
#         "nombre": "Osvaldo",
#         "apellido": "Cuervo",
#         "direccion": "C 6.0",
#         "localidad": "PUNTAS DE VALDEZ",
#         "departamento": "SAN JOSE",
#         "latitud": -34.5866324940541,
#         "longitud": -56.7052831179473,
#         "cedula": "74555180",
#         "fecha_nacimiento": "2005-12-11",
#         "fecha_inicio_sintomas": "2024-04-16",
#         "edad": 18,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "4342 2017",
#         "celular": "092868975",
#         "prestador": "ASOCIACION ESPAÑOLA",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "Bacilos Gram negativos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 49.0,
#         "Proteínas en LCR (mg/dl)": 34.6,
#         "Leucocitos LCR (/mm3)": 4625,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Conrado",
#         "apellido": "Tejero",
#         "direccion": "ZELMAR MICHELINI 883.0",
#         "localidad": "MELO",
#         "departamento": "CERRO LARGO",
#         "latitud": -32.366970450025,
#         "longitud": -54.1607603093299,
#         "cedula": "10964232",
#         "fecha_nacimiento": "1975-02-10",
#         "fecha_inicio_sintomas": "2024-04-02",
#         "edad": 49,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "4640 1418",
#         "celular": "093290787",
#         "prestador": "ASSE",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "N",
#         "Convulsión": "N",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "Bacilos Gram negativos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 63.9,
#         "Proteínas en LCR (mg/dl)": 47.7,
#         "Leucocitos LCR (/mm3)": 9216,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Lidia",
#         "apellido": "Canales",
#         "direccion": "",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.4207133621853,
#         "longitud": -56.456234326355,
#         "cedula": "99349801",
#         "fecha_nacimiento": "2000-11-24",
#         "fecha_inicio_sintomas": "2024-01-19",
#         "edad": 23,
#         "sexo": "F",
#         "evento": "Dengue",
#         "telefono": "4776 3032",
#         "celular": "094897188",
#         "prestador": "ASSE",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "N",
#         "Dolor abdominal intenso y continuo": "S",
#         "Cefalea": "N",
#         "Edemas": "S",
#         "Dolor retroorbitario": "S",
#         "Sangrado de Mucosas": "N",
#         "Nauseas/Vómitos": "N",
#         "Sangrado Grave": "N",
#         "Exantema": "S",
#         "Letargia o irritabilidad": "S",
#         "Mialgias y/o artralgias": "N",
#         "Shock": "S",
#         "Hematocrito (%)": 27,
#         "Plaquetas (/mm3)": 286101,
#         "Leucocitos sangre (/mm3)": 4166
#     },
#     {
#         "nombre": "Eloísa",
#         "apellido": "Salazar",
#         "direccion": "TREINTA Y TRES 40.0",
#         "localidad": "CANELONES",
#         "departamento": "CANELONES",
#         "latitud": -34.5178855498562,
#         "longitud": -56.2808064914806,
#         "cedula": "10431065",
#         "fecha_nacimiento": "1998-11-29",
#         "fecha_inicio_sintomas": "2024-07-01",
#         "edad": 25,
#         "sexo": "F",
#         "evento": "Dengue",
#         "telefono": "4333 1351",
#         "celular": "096314654",
#         "prestador": "MEDICA URUGUAYA",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Dolor abdominal intenso y continuo": "N",
#         "Cefalea": "N",
#         "Edemas": "N",
#         "Dolor retroorbitario": "N",
#         "Sangrado de Mucosas": "S",
#         "Nauseas/Vómitos": "N",
#         "Sangrado Grave": "S",
#         "Exantema": "N",
#         "Letargia o irritabilidad": "S",
#         "Mialgias y/o artralgias": "S",
#         "Shock": "N",
#         "Hematocrito (%)": 27,
#         "Plaquetas (/mm3)": 569542,
#         "Leucocitos sangre (/mm3)": 30008
#     },
#     {
#         "nombre": "Gerardo",
#         "apellido": "Llanos",
#         "direccion": "CALLAO 3493.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8535611065885,
#         "longitud": -56.1538718470175,
#         "cedula": "27971517",
#         "fecha_nacimiento": "1984-02-20",
#         "fecha_inicio_sintomas": "2024-07-23",
#         "edad": 40,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "2544 6983",
#         "celular": "097258338",
#         "prestador": "HOSPITAL EVANGELICO",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Convulsión": "N",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "Cocos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 81.5,
#         "Proteínas en LCR (mg/dl)": 43.9,
#         "Leucocitos LCR (/mm3)": 8701,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Carlos",
#         "apellido": "Peñas",
#         "direccion": "18 DE JULIO 934.0",
#         "localidad": "SAN JOSE DE MAYO",
#         "departamento": "SAN JOSE",
#         "latitud": -34.3371224645014,
#         "longitud": -56.7036757862076,
#         "cedula": "40582816",
#         "fecha_nacimiento": "1997-04-04",
#         "fecha_inicio_sintomas": "2024-03-26",
#         "edad": 26,
#         "sexo": "M",
#         "evento": "Dengue",
#         "telefono": "4345 4586",
#         "celular": "094837892",
#         "prestador": "HOSPITAL EVANGELICO",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Dolor abdominal intenso y continuo": "N",
#         "Cefalea": "N",
#         "Edemas": "N",
#         "Dolor retroorbitario": "N",
#         "Sangrado de Mucosas": "N",
#         "Nauseas/Vómitos": "N",
#         "Sangrado Grave": "S",
#         "Exantema": "S",
#         "Letargia o irritabilidad": "S",
#         "Mialgias y/o artralgias": "N",
#         "Shock": "S",
#         "Hematocrito (%)": 58,
#         "Plaquetas (/mm3)": 1405012,
#         "Leucocitos sangre (/mm3)": 2908
#     },
#     {
#         "nombre": "Fabricio",
#         "apellido": "Almagro",
#         "direccion": "LAVALLEJA 45.0",
#         "localidad": "LA FLORESTA",
#         "departamento": "CANELONES",
#         "latitud": -34.7563466129681,
#         "longitud": -55.6781057149174,
#         "cedula": "93073923",
#         "fecha_nacimiento": "1955-10-28",
#         "fecha_inicio_sintomas": "2024-08-07",
#         "edad": 68,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4331 6164",
#         "celular": "095901072",
#         "prestador": "CRAMI IAMPP",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "S",
#         "Directo LCR": "Cocos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 67.3,
#         "Proteínas en LCR (mg/dl)": 17.1,
#         "Leucocitos LCR (/mm3)": 6073,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Abilio",
#         "apellido": "Villanueva",
#         "direccion": "AMAZONAS 1463.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8945494776357,
#         "longitud": -56.1010911185846,
#         "cedula": "57516220",
#         "fecha_nacimiento": "1933-11-18",
#         "fecha_inicio_sintomas": "2024-03-19",
#         "edad": 90,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "2250 2168",
#         "celular": "094859423",
#         "prestador": "COSEM IAMPP",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "S",
#         "Convulsión": "N",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "N",
#         "Directo LCR": "Bacilos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 94.0,
#         "Proteínas en LCR (mg/dl)": 48.3,
#         "Leucocitos LCR (/mm3)": 5188,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Micaela",
#         "apellido": "Gomila",
#         "direccion": "SAUCE OROÑO 8.0",
#         "localidad": NaN,
#         "departamento": "FLORIDA",
#         "latitud": -33.5204760544767,
#         "longitud": -56.4897543853208,
#         "cedula": "39930486",
#         "fecha_nacimiento": "2021-08-21",
#         "fecha_inicio_sintomas": "2024-07-01",
#         "edad": 2,
#         "sexo": "F",
#         "evento": "Dengue",
#         "telefono": "4359 9427",
#         "celular": "094020159",
#         "prestador": "CIRCULO CATOLICO",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Dolor abdominal intenso y continuo": "S",
#         "Cefalea": "N",
#         "Edemas": "S",
#         "Dolor retroorbitario": "S",
#         "Sangrado de Mucosas": "N",
#         "Nauseas/Vómitos": "S",
#         "Sangrado Grave": "N",
#         "Exantema": "N",
#         "Letargia o irritabilidad": "S",
#         "Mialgias y/o artralgias": "N",
#         "Shock": "N",
#         "Hematocrito (%)": 50,
#         "Plaquetas (/mm3)": 1335180,
#         "Leucocitos sangre (/mm3)": 23816
#     },
#     {
#         "nombre": "Coral",
#         "apellido": "Sanjuan",
#         "direccion": "GENERAL ENRIQUE MARTINEZ 1285.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8734141732507,
#         "longitud": -56.1917435273572,
#         "cedula": "73319010",
#         "fecha_nacimiento": "1947-02-26",
#         "fecha_inicio_sintomas": "2024-04-06",
#         "edad": 77,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "2822 7457",
#         "celular": "098318450",
#         "prestador": "UNIVERSAL",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Convulsión": "N",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "Bacilos Gram positivos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 74.9,
#         "Proteínas en LCR (mg/dl)": 31.9,
#         "Leucocitos LCR (/mm3)": 6841,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Hernando",
#         "apellido": "Cervera",
#         "direccion": "",
#         "localidad": "BALTASAR BRUM",
#         "departamento": "ARTIGAS",
#         "latitud": -30.7289692264066,
#         "longitud": -57.3258893132628,
#         "cedula": "30495435",
#         "fecha_nacimiento": "1952-07-06",
#         "fecha_inicio_sintomas": "2024-05-22",
#         "edad": 71,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "4773 4705",
#         "celular": "098075054",
#         "prestador": "GREMEDA IAMPP",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Convulsión": "N",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "N",
#         "Directo LCR": "Bacilos Gram negativos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 14.2,
#         "Proteínas en LCR (mg/dl)": 40.0,
#         "Leucocitos LCR (/mm3)": 2727,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Sosimo",
#         "apellido": "Blázquez",
#         "direccion": "DE HERRERA, DR. JUAN (SONRISA) 28.0",
#         "localidad": "LA SONRISA",
#         "departamento": "MALDONADO",
#         "latitud": -34.8935050483154,
#         "longitud": -54.9723973089502,
#         "cedula": "66589838",
#         "fecha_nacimiento": "1983-03-27",
#         "fecha_inicio_sintomas": "2024-05-19",
#         "edad": 41,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4227 6348",
#         "celular": "093679804",
#         "prestador": "MEDICA URUGUAYA",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "Bacilos Gram negativos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 74.2,
#         "Proteínas en LCR (mg/dl)": 42.6,
#         "Leucocitos LCR (/mm3)": 2794,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Renato",
#         "apellido": "Balaguer",
#         "direccion": "CONCEPCION ARENAL 1572.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8796333327119,
#         "longitud": -56.1850721720448,
#         "cedula": "10114463",
#         "fecha_nacimiento": "1966-08-30",
#         "fecha_inicio_sintomas": "2024-02-24",
#         "edad": 57,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "2690 3331",
#         "celular": "096666674",
#         "prestador": "SEGURO AMERICANO",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "S",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 60.7,
#         "Proteínas en LCR (mg/dl)": 18.0,
#         "Leucocitos LCR (/mm3)": 7439,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Rodolfo",
#         "apellido": "Redondo",
#         "direccion": "JOSE PEDRO VARELA 1185.0",
#         "localidad": "MELO",
#         "departamento": "CERRO LARGO",
#         "latitud": -32.3733688661912,
#         "longitud": -54.158187827062,
#         "cedula": "36301793",
#         "fecha_nacimiento": "1977-03-24",
#         "fecha_inicio_sintomas": "2024-02-01",
#         "edad": 46,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4644 7932",
#         "celular": "098341467",
#         "prestador": "MEDICA URUGUAYA",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 96.1,
#         "Proteínas en LCR (mg/dl)": 47.0,
#         "Leucocitos LCR (/mm3)": 7767,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Raúl",
#         "apellido": "Comas",
#         "direccion": "RODO, JOSE E. 524.0",
#         "localidad": "MERCEDES",
#         "departamento": "SORIANO",
#         "latitud": -33.2512591162101,
#         "longitud": -58.0338942304442,
#         "cedula": "57631591",
#         "fecha_nacimiento": "1988-06-23",
#         "fecha_inicio_sintomas": "2024-05-14",
#         "edad": 35,
#         "sexo": "M",
#         "evento": "Dengue",
#         "telefono": "4530 6723",
#         "celular": "097434386",
#         "prestador": "CAMS IAMPP",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Dolor abdominal intenso y continuo": "S",
#         "Cefalea": "N",
#         "Edemas": "S",
#         "Dolor retroorbitario": "N",
#         "Sangrado de Mucosas": "N",
#         "Nauseas/Vómitos": "S",
#         "Sangrado Grave": "S",
#         "Exantema": "S",
#         "Letargia o irritabilidad": "S",
#         "Mialgias y/o artralgias": "N",
#         "Shock": "S",
#         "Hematocrito (%)": 31,
#         "Plaquetas (/mm3)": 130536,
#         "Leucocitos sangre (/mm3)": 25462
#     },
#     {
#         "nombre": "Danilo",
#         "apellido": "Expósito",
#         "direccion": "EJIDO 987.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.9124892261773,
#         "longitud": -56.1862154408294,
#         "cedula": "12839233",
#         "fecha_nacimiento": "1971-03-04",
#         "fecha_inicio_sintomas": "2024-03-14",
#         "edad": 53,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "2740 2096",
#         "celular": "092161103",
#         "prestador": "SMI",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 51.7,
#         "Proteínas en LCR (mg/dl)": 48.1,
#         "Leucocitos LCR (/mm3)": 5202,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Macaria",
#         "apellido": "Solana",
#         "direccion": "MAIPU 1957.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8915986340197,
#         "longitud": -56.1471226546264,
#         "cedula": "10359475",
#         "fecha_nacimiento": "1949-10-07",
#         "fecha_inicio_sintomas": "2024-01-26",
#         "edad": 74,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "2228 0428",
#         "celular": "092286064",
#         "prestador": "CIRCULO CATOLICO",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "N",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 34.4,
#         "Proteínas en LCR (mg/dl)": 41.9,
#         "Leucocitos LCR (/mm3)": 9083,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Gerónimo",
#         "apellido": "Ródenas",
#         "direccion": "GRAL. JOSE G. ARTIGAS 1660.0",
#         "localidad": "RIVERA",
#         "departamento": "RIVERA",
#         "latitud": -30.9064740922774,
#         "longitud": -55.5298722524401,
#         "cedula": "58388674",
#         "fecha_nacimiento": "1935-06-05",
#         "fecha_inicio_sintomas": "2024-01-12",
#         "edad": 88,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "4623 0820",
#         "celular": "092029095",
#         "prestador": "COMERI",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "S",
#         "Directo LCR": "Cocos Gram negativos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 40.5,
#         "Proteínas en LCR (mg/dl)": 41.2,
#         "Leucocitos LCR (/mm3)": 1819,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Adelaida",
#         "apellido": "Amigó",
#         "direccion": "",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.4096402874416,
#         "longitud": -56.4808665988836,
#         "cedula": "76048993",
#         "fecha_nacimiento": "1950-12-06",
#         "fecha_inicio_sintomas": "2024-07-26",
#         "edad": 73,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "4772 6098",
#         "celular": "092335328",
#         "prestador": "GREMEDA IAMPP",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Convulsión": "N",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "Bacilos Gram positivos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 17.8,
#         "Proteínas en LCR (mg/dl)": 30.1,
#         "Leucocitos LCR (/mm3)": 7066,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Liliana",
#         "apellido": "Quirós",
#         "direccion": "MONTEVIDEO 53.0",
#         "localidad": "PAYSANDU",
#         "departamento": "PAYSANDU",
#         "latitud": -32.3317229062419,
#         "longitud": -58.0891068986935,
#         "cedula": "66202830",
#         "fecha_nacimiento": "1940-05-17",
#         "fecha_inicio_sintomas": "2024-07-15",
#         "edad": 84,
#         "sexo": "F",
#         "evento": "Dengue",
#         "telefono": "4724 5794",
#         "celular": "092556621",
#         "prestador": "COMEPA",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Dolor abdominal intenso y continuo": "S",
#         "Cefalea": "S",
#         "Edemas": "S",
#         "Dolor retroorbitario": "N",
#         "Sangrado de Mucosas": "S",
#         "Nauseas/Vómitos": "N",
#         "Sangrado Grave": "S",
#         "Exantema": "S",
#         "Letargia o irritabilidad": "N",
#         "Mialgias y/o artralgias": "N",
#         "Shock": "N",
#         "Hematocrito (%)": 45,
#         "Plaquetas (/mm3)": 678190,
#         "Leucocitos sangre (/mm3)": 18649
#     },
#     {
#         "nombre": "Piedad",
#         "apellido": "Belmonte",
#         "direccion": "JUAN DE DIOS PEZA 2133.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8834905816547,
#         "longitud": -56.1356701091975,
#         "cedula": "94423701",
#         "fecha_nacimiento": "1996-09-02",
#         "fecha_inicio_sintomas": "2024-01-31",
#         "edad": 27,
#         "sexo": "F",
#         "evento": "Dengue",
#         "telefono": "2160 9105",
#         "celular": "093909620",
#         "prestador": "CIRCULO CATOLICO",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Dolor abdominal intenso y continuo": "N",
#         "Cefalea": "S",
#         "Edemas": "N",
#         "Dolor retroorbitario": "S",
#         "Sangrado de Mucosas": "S",
#         "Nauseas/Vómitos": "S",
#         "Sangrado Grave": "S",
#         "Exantema": "N",
#         "Letargia o irritabilidad": "N",
#         "Mialgias y/o artralgias": "S",
#         "Shock": "S",
#         "Hematocrito (%)": 21,
#         "Plaquetas (/mm3)": 1307932,
#         "Leucocitos sangre (/mm3)": 16147
#     },
#     {
#         "nombre": "Nicolasa",
#         "apellido": "Murillo",
#         "direccion": "",
#         "localidad": "BELLA UNION",
#         "departamento": "ARTIGAS",
#         "latitud": -30.2569562388527,
#         "longitud": -57.5883526151204,
#         "cedula": "17924798",
#         "fecha_nacimiento": "1945-08-18",
#         "fecha_inicio_sintomas": "2024-07-22",
#         "edad": 78,
#         "sexo": "F",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4770 5116",
#         "celular": "097427590",
#         "prestador": "GREMEDA IAMPP",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 31.5,
#         "Proteínas en LCR (mg/dl)": 36.8,
#         "Leucocitos LCR (/mm3)": 4604,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Josep",
#         "apellido": "Polo",
#         "direccion": "BATLLE Y ORDOÑEZ, JOSE 585.0",
#         "localidad": "SAN JOSE DE MAYO",
#         "departamento": "SAN JOSE",
#         "latitud": -34.3391918039772,
#         "longitud": -56.7123377797042,
#         "cedula": "40009155",
#         "fecha_nacimiento": "1947-05-10",
#         "fecha_inicio_sintomas": "2024-07-02",
#         "edad": 77,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "4343 1673",
#         "celular": "095487220",
#         "prestador": "GREMCA",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "S",
#         "Convulsión": "N",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "S",
#         "Directo LCR": "Bacilos Gram negativos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 59.1,
#         "Proteínas en LCR (mg/dl)": 24.5,
#         "Leucocitos LCR (/mm3)": 5254,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Alberto",
#         "apellido": "Blanca",
#         "direccion": "FRANCISCO DE LOS SANTOS 3.0",
#         "localidad": "MALDONADO",
#         "departamento": "MALDONADO",
#         "latitud": -34.9132147624269,
#         "longitud": -54.9676354964525,
#         "cedula": "44070201",
#         "fecha_nacimiento": "2017-04-02",
#         "fecha_inicio_sintomas": "2024-05-17",
#         "edad": 7,
#         "sexo": "M",
#         "evento": "Leptospirosis",
#         "telefono": "4251 0939",
#         "celular": "092488065",
#         "prestador": "AMDM IAMPP",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Cefalea": "S",
#         "Síndrome hemorragíparo": "N",
#         "Mialgias y/o artralgias": "N",
#         "Compromiso renal": "N",
#         "Compromiso hepático": "S",
#         "Sintomatología digestiva": "S",
#         "Ictericia": "S",
#         "Hiperemia conjuntival": "S",
#         "Neumonia/Neumonitis": "S",
#         "Lesiones de piel": "N",
#         "Hematocrito (%)": 46,
#         "Plaquetas (/mm3)": 920711,
#         "Leucocitos sangre (/mm3)": 34365,
#         "Función hepática BT (mg/dl)": 2.1,
#         "Función hepática TGO (UI/l)": 96.8,
#         "Función hepática LDH (mg/dl)": 808,
#         "Función hepática TGP (UI/l)": 75,
#         "Función renal azoemia (mg/dl)": 27.5,
#         "Función renal creatinemia (mg/dl)": 4.2
#     },
#     {
#         "nombre": "Maristela",
#         "apellido": "Andrade",
#         "direccion": "DALMIRO COSTA 4168.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.893651868916,
#         "longitud": -56.1252359363043,
#         "cedula": "55428227",
#         "fecha_nacimiento": "1980-10-19",
#         "fecha_inicio_sintomas": "2024-04-11",
#         "edad": 43,
#         "sexo": "F",
#         "evento": "Leptospirosis",
#         "telefono": "2391 1079",
#         "celular": "091266210",
#         "prestador": "CUDAM",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Cefalea": "S",
#         "Síndrome hemorragíparo": "N",
#         "Mialgias y/o artralgias": "N",
#         "Compromiso renal": "S",
#         "Compromiso hepático": "N",
#         "Sintomatología digestiva": "N",
#         "Ictericia": "S",
#         "Hiperemia conjuntival": "S",
#         "Neumonia/Neumonitis": "N",
#         "Lesiones de piel": "S",
#         "Hematocrito (%)": 38,
#         "Plaquetas (/mm3)": 58008,
#         "Leucocitos sangre (/mm3)": 4287,
#         "Función hepática BT (mg/dl)": 11.3,
#         "Función hepática TGO (UI/l)": 52.8,
#         "Función hepática LDH (mg/dl)": 1022,
#         "Función hepática TGP (UI/l)": 153,
#         "Función renal azoemia (mg/dl)": 21.0,
#         "Función renal creatinemia (mg/dl)": 9.3
#     },
#     {
#         "nombre": "Flor",
#         "apellido": "Gilabert",
#         "direccion": "INTENDENTE SUAREZ 162.0",
#         "localidad": "COLONIA DEL SACRAMENTO",
#         "departamento": "COLONIA",
#         "latitud": -34.4713017967389,
#         "longitud": -57.8470970037791,
#         "cedula": "68318013",
#         "fecha_nacimiento": "1980-09-26",
#         "fecha_inicio_sintomas": "2024-01-25",
#         "edad": 43,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "4522 6951",
#         "celular": "096162756",
#         "prestador": "CAMEC",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "S",
#         "Directo LCR": "Cocos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 90.0,
#         "Proteínas en LCR (mg/dl)": 28.9,
#         "Leucocitos LCR (/mm3)": 5955,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Piedad",
#         "apellido": "Toledo",
#         "direccion": "A DOCE METROS 5290.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8260151263124,
#         "longitud": -56.1746840439683,
#         "cedula": "14178405",
#         "fecha_nacimiento": "2014-05-07",
#         "fecha_inicio_sintomas": "2024-04-25",
#         "edad": 9,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "2160 9627",
#         "celular": "091449982",
#         "prestador": "CUDAM",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "N",
#         "Directo LCR": "Cocos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 22.7,
#         "Proteínas en LCR (mg/dl)": 15.4,
#         "Leucocitos LCR (/mm3)": 158,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Isaura",
#         "apellido": "Madrid",
#         "direccion": "PASAJE PLATA 4497.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8717878846396,
#         "longitud": -56.2713369141646,
#         "cedula": "37380368",
#         "fecha_nacimiento": "1949-05-26",
#         "fecha_inicio_sintomas": "2024-06-04",
#         "edad": 75,
#         "sexo": "F",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "2747 7314",
#         "celular": "094010619",
#         "prestador": "UNIVERSAL",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "Bacilos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 18.4,
#         "Proteínas en LCR (mg/dl)": 33.4,
#         "Leucocitos LCR (/mm3)": 6667,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Prudencio",
#         "apellido": "Bellido",
#         "direccion": "DURAZNO 912.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.9110354303386,
#         "longitud": -56.1962231676406,
#         "cedula": "35052466",
#         "fecha_nacimiento": "1976-05-11",
#         "fecha_inicio_sintomas": "2024-04-23",
#         "edad": 47,
#         "sexo": "M",
#         "evento": "Leptospirosis",
#         "telefono": "2802 7145",
#         "celular": "095853546",
#         "prestador": "CUDAM",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Cefalea": "N",
#         "Síndrome hemorragíparo": "S",
#         "Mialgias y/o artralgias": "S",
#         "Compromiso renal": "S",
#         "Compromiso hepático": "N",
#         "Sintomatología digestiva": "N",
#         "Ictericia": "N",
#         "Hiperemia conjuntival": "S",
#         "Neumonia/Neumonitis": "S",
#         "Lesiones de piel": "N",
#         "Hematocrito (%)": 32,
#         "Plaquetas (/mm3)": 1134911,
#         "Leucocitos sangre (/mm3)": 12643,
#         "Función hepática BT (mg/dl)": 0.6,
#         "Función hepática TGO (UI/l)": 119.3,
#         "Función hepática LDH (mg/dl)": 273,
#         "Función hepática TGP (UI/l)": 155,
#         "Función renal azoemia (mg/dl)": 97.4,
#         "Función renal creatinemia (mg/dl)": 8.4
#     },
#     {
#         "nombre": "Verónica",
#         "apellido": "Ayala",
#         "direccion": "CINCO PEATONAL OCHO METROS 4575.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8192860000011,
#         "longitud": -56.1340479999999,
#         "cedula": "16680646",
#         "fecha_nacimiento": "1987-02-25",
#         "fecha_inicio_sintomas": "2024-06-18",
#         "edad": 37,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "2252 1382",
#         "celular": "095743718",
#         "prestador": "CUDAM",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "S",
#         "Convulsión": "N",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 43.2,
#         "Proteínas en LCR (mg/dl)": 15.0,
#         "Leucocitos LCR (/mm3)": 4230,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Marcial",
#         "apellido": "Múgica",
#         "direccion": "AVDA. SORIANO 27.0",
#         "localidad": "PAYSANDU",
#         "departamento": "PAYSANDU",
#         "latitud": -32.3275041488546,
#         "longitud": -58.0709369384043,
#         "cedula": "20101466",
#         "fecha_nacimiento": "1994-03-11",
#         "fecha_inicio_sintomas": "2024-02-01",
#         "edad": 29,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "4729 7751",
#         "celular": "095981846",
#         "prestador": "ASSE",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "Cocos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 36.5,
#         "Proteínas en LCR (mg/dl)": 19.0,
#         "Leucocitos LCR (/mm3)": 9927,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Benigno",
#         "apellido": "Ferrera",
#         "direccion": "BENELLI, CONSEJAL JOSE 2.0",
#         "localidad": "TACUAREMBO",
#         "departamento": "TACUAREMBO",
#         "latitud": -31.715326264831,
#         "longitud": -55.9969665427209,
#         "cedula": "10161892",
#         "fecha_nacimiento": "2017-12-07",
#         "fecha_inicio_sintomas": "2024-01-02",
#         "edad": 6,
#         "sexo": "M",
#         "evento": "Dengue",
#         "telefono": "4638 2577",
#         "celular": "092334473",
#         "prestador": "MEDICA URUGUAYA",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Dolor abdominal intenso y continuo": "S",
#         "Cefalea": "N",
#         "Edemas": "N",
#         "Dolor retroorbitario": "N",
#         "Sangrado de Mucosas": "S",
#         "Nauseas/Vómitos": "S",
#         "Sangrado Grave": "N",
#         "Exantema": "S",
#         "Letargia o irritabilidad": "N",
#         "Mialgias y/o artralgias": "N",
#         "Shock": "N",
#         "Hematocrito (%)": 26,
#         "Plaquetas (/mm3)": 133395,
#         "Leucocitos sangre (/mm3)": 28465
#     },
#     {
#         "nombre": "Marino",
#         "apellido": "Mateu",
#         "direccion": "ARTIGAS, 3 GRAL. JOSE 6.0",
#         "localidad": NaN,
#         "departamento": "RIO NEGRO",
#         "latitud": -32.6926114822556,
#         "longitud": -57.6418605648904,
#         "cedula": "53988734",
#         "fecha_nacimiento": "1966-12-18",
#         "fecha_inicio_sintomas": "2024-06-30",
#         "edad": 57,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4565 4873",
#         "celular": "095588366",
#         "prestador": "HOSPITAL EVANGELICO",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "N",
#         "Directo LCR": "Cocos Gram negativos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 55.3,
#         "Proteínas en LCR (mg/dl)": 29.4,
#         "Leucocitos LCR (/mm3)": 6994,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Mohamed",
#         "apellido": "Barroso",
#         "direccion": "DOCTOR FRANCISCO SIMON 1997.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8887288944252,
#         "longitud": -56.1432888226468,
#         "cedula": "96706824",
#         "fecha_nacimiento": "2011-01-28",
#         "fecha_inicio_sintomas": "2024-06-25",
#         "edad": 13,
#         "sexo": "M",
#         "evento": "Leptospirosis",
#         "telefono": "2268 0009",
#         "celular": "091273949",
#         "prestador": "COSEM IAMPP",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Cefalea": "S",
#         "Síndrome hemorragíparo": "N",
#         "Mialgias y/o artralgias": "N",
#         "Compromiso renal": "S",
#         "Compromiso hepático": "N",
#         "Sintomatología digestiva": "N",
#         "Ictericia": "N",
#         "Hiperemia conjuntival": "N",
#         "Neumonia/Neumonitis": "S",
#         "Lesiones de piel": "N",
#         "Hematocrito (%)": 38,
#         "Plaquetas (/mm3)": 509673,
#         "Leucocitos sangre (/mm3)": 30879,
#         "Función hepática BT (mg/dl)": 4.1,
#         "Función hepática TGO (UI/l)": 80.8,
#         "Función hepática LDH (mg/dl)": 1407,
#         "Función hepática TGP (UI/l)": 182,
#         "Función renal azoemia (mg/dl)": 9.0,
#         "Función renal creatinemia (mg/dl)": 3.7
#     },
#     {
#         "nombre": "Ismael",
#         "apellido": "Izaguirre",
#         "direccion": "",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.4168974196707,
#         "longitud": -56.4713010550303,
#         "cedula": "26136223",
#         "fecha_nacimiento": "1972-06-09",
#         "fecha_inicio_sintomas": "2024-02-21",
#         "edad": 51,
#         "sexo": "M",
#         "evento": "Leptospirosis",
#         "telefono": "4779 6391",
#         "celular": "091213213",
#         "prestador": "ASSE",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Cefalea": "N",
#         "Síndrome hemorragíparo": "N",
#         "Mialgias y/o artralgias": "N",
#         "Compromiso renal": "N",
#         "Compromiso hepático": "S",
#         "Sintomatología digestiva": "S",
#         "Ictericia": "N",
#         "Hiperemia conjuntival": "N",
#         "Neumonia/Neumonitis": "N",
#         "Lesiones de piel": "S",
#         "Hematocrito (%)": 43,
#         "Plaquetas (/mm3)": 170445,
#         "Leucocitos sangre (/mm3)": 39208,
#         "Función hepática BT (mg/dl)": 8.8,
#         "Función hepática TGO (UI/l)": 37.7,
#         "Función hepática LDH (mg/dl)": 863,
#         "Función hepática TGP (UI/l)": 175,
#         "Función renal azoemia (mg/dl)": 87.3,
#         "Función renal creatinemia (mg/dl)": 8.4
#     },
#     {
#         "nombre": "Eva María",
#         "apellido": "Saavedra",
#         "direccion": "ESPINOLA,MARIA 1043.0",
#         "localidad": "SAN JOSE DE MAYO",
#         "departamento": "SAN JOSE",
#         "latitud": -34.3321340727727,
#         "longitud": -56.7241206729805,
#         "cedula": "10323541",
#         "fecha_nacimiento": "1961-07-04",
#         "fecha_inicio_sintomas": "2024-07-12",
#         "edad": 63,
#         "sexo": "F",
# ...
#         "Paciente Grave": "S",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 34.7,
#         "Proteínas en LCR (mg/dl)": 45.9,
#         "Leucocitos LCR (/mm3)": 2002,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Catalina",
#         "apellido": "Arjona",
#         "direccion": "1 9378.0",
#         "localidad": "MINAS DE CORRALES",
#         "departamento": "RIVERA",
#         "latitud": -31.5750069627242,
#         "longitud": -55.4699067253959,
#         "cedula": "36404571",
#         "fecha_nacimiento": "1996-07-13",
#         "fecha_inicio_sintomas": "2024-07-21",
#         "edad": 28,
#         "sexo": "F",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4621 8569",
#         "celular": "099753924",
#         "prestador": "MEDICA URUGUAYA",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "S",
#         "Convulsión": "N",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 14.8,
#         "Proteínas en LCR (mg/dl)": 30.5,
#         "Leucocitos LCR (/mm3)": 1007,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Berto",
#         "apellido": "Mayoral",
#         "direccion": "ATENAS 3063.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8320119300454,
#         "longitud": -56.1421542123358,
#         "cedula": "54604212",
#         "fecha_nacimiento": "1963-10-29",
#         "fecha_inicio_sintomas": "2024-02-15",
#         "edad": 60,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "2210 3890",
#         "celular": "096777548",
#         "prestador": "SEGURO AMERICANO",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "Bacilos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 59.8,
#         "Proteínas en LCR (mg/dl)": 46.7,
#         "Leucocitos LCR (/mm3)": 429,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Atilio",
#         "apellido": "Sans",
#         "direccion": "",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.4173306961942,
#         "longitud": -56.4779529803192,
#         "cedula": "61881699",
#         "fecha_nacimiento": "1948-06-18",
#         "fecha_inicio_sintomas": "2024-07-20",
#         "edad": 76,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4774 4761",
#         "celular": "096832648",
#         "prestador": "GREMEDA IAMPP",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "N",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 55.7,
#         "Proteínas en LCR (mg/dl)": 35.1,
#         "Leucocitos LCR (/mm3)": 5994,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Jimena",
#         "apellido": "Jove",
#         "direccion": "",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.4089757195004,
#         "longitud": -56.4730544393145,
#         "cedula": "10029022",
#         "fecha_nacimiento": "1996-02-13",
#         "fecha_inicio_sintomas": "2024-03-21",
#         "edad": 28,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "4778 1448",
#         "celular": "096867608",
#         "prestador": "COMERI",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "N",
#         "Convulsión": "N",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "N",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 46.8,
#         "Proteínas en LCR (mg/dl)": 22.0,
#         "Leucocitos LCR (/mm3)": 3688,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Jordana",
#         "apellido": "Hurtado",
#         "direccion": "PASAJE PLATA 4510.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8727822427998,
#         "longitud": -56.2708597031727,
#         "cedula": "18752752",
#         "fecha_nacimiento": "2009-10-28",
#         "fecha_inicio_sintomas": "2024-04-02",
#         "edad": 14,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "2399 1410",
#         "celular": "092313432",
#         "prestador": "ASOCIACION ESPAÑOLA",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "S",
#         "Directo LCR": "Cocos Gram negativos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 50.2,
#         "Proteínas en LCR (mg/dl)": 23.6,
#         "Leucocitos LCR (/mm3)": 7765,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Flor",
#         "apellido": "Agullo",
#         "direccion": "RAMBLA 3914.0",
#         "localidad": "CIUDAD DE LA COSTA",
#         "departamento": "CANELONES",
#         "latitud": -34.8556322824063,
#         "longitud": -55.989271182359,
#         "cedula": "86585537",
#         "fecha_nacimiento": "1953-01-31",
#         "fecha_inicio_sintomas": "2024-03-24",
#         "edad": 71,
#         "sexo": "F",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4337 6362",
#         "celular": "097759995",
#         "prestador": "CUDAM",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "Cocos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 2.2,
#         "Proteínas en LCR (mg/dl)": 36.7,
#         "Leucocitos LCR (/mm3)": 3935,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Ruben",
#         "apellido": "Cervera",
#         "direccion": "PASAJE TRESCIENTOS SESENTA Y SIETE 2024.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.8796380000011,
#         "longitud": -56.0993769999999,
#         "cedula": "87598527",
#         "fecha_nacimiento": "1945-08-30",
#         "fecha_inicio_sintomas": "2024-02-28",
#         "edad": 78,
#         "sexo": "M",
#         "evento": "Meningitis Viral",
#         "telefono": "2392 7750",
#         "celular": "095275825",
#         "prestador": "GREMCA",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "S",
#         "Directo LCR": "No se observan bacterias",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 79.9,
#         "Proteínas en LCR (mg/dl)": 19.3,
#         "Leucocitos LCR (/mm3)": 4817,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Manu",
#         "apellido": "Sevilla",
#         "direccion": "12 DE OCTUBRE 351.0",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.397586552773,
#         "longitud": -56.4604162627953,
#         "cedula": "15111654",
#         "fecha_nacimiento": "1961-11-18",
#         "fecha_inicio_sintomas": "2024-07-31",
#         "edad": 62,
#         "sexo": "M",
#         "evento": "Leptospirosis",
#         "telefono": "4776 3335",
#         "celular": "098921255",
#         "prestador": "ASSE",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Cefalea": "S",
#         "Síndrome hemorragíparo": "S",
#         "Mialgias y/o artralgias": "N",
#         "Compromiso renal": "N",
#         "Compromiso hepático": "S",
#         "Sintomatología digestiva": "N",
#         "Ictericia": "N",
#         "Hiperemia conjuntival": "S",
#         "Neumonia/Neumonitis": "S",
#         "Lesiones de piel": "S",
#         "Hematocrito (%)": 35,
#         "Plaquetas (/mm3)": 1364930,
#         "Leucocitos sangre (/mm3)": 17895,
#         "Función hepática BT (mg/dl)": 10.1,
#         "Función hepática TGO (UI/l)": 72.0,
#         "Función hepática LDH (mg/dl)": 756,
#         "Función hepática TGP (UI/l)": 107,
#         "Función renal azoemia (mg/dl)": 70.4,
#         "Función renal creatinemia (mg/dl)": 2.2
#     },
#     {
#         "nombre": "Cipriano",
#         "apellido": "Tur",
#         "direccion": "",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.4174024166844,
#         "longitud": -56.4637173774609,
#         "cedula": "42872043",
#         "fecha_nacimiento": "1942-08-24",
#         "fecha_inicio_sintomas": "2024-05-09",
#         "edad": 81,
#         "sexo": "M",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4772 8446",
#         "celular": "098699574",
#         "prestador": "ASSE",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "S",
#         "Paciente Grave": "S",
#         "Directo LCR": "Cocos Gram negativos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 5.1,
#         "Proteínas en LCR (mg/dl)": 44.8,
#         "Leucocitos LCR (/mm3)": 6256,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "Brunilda",
#         "apellido": "Alvarez",
#         "direccion": "",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.4217314974644,
#         "longitud": -56.4611204326339,
#         "cedula": "78659790",
#         "fecha_nacimiento": "1942-03-09",
#         "fecha_inicio_sintomas": "2024-05-21",
#         "edad": 82,
#         "sexo": "F",
#         "evento": "Meningitis Viral",
#         "telefono": "4773 7555",
#         "celular": "094055155",
#         "prestador": "COMERI",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "S",
#         "Convulsión": "S",
#         "Petequias": "N",
#         "Signos de irritación meníngea": "S",
#         "Alteración de conciencia": "S",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "Bacilos Gram positivos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 37.4,
#         "Proteínas en LCR (mg/dl)": 31.7,
#         "Leucocitos LCR (/mm3)": 4073,
#         "Predominio": "PMN"
#     },
#     {
#         "nombre": "Abel",
#         "apellido": "Ferreras",
#         "direccion": "GRITO DE ASENCIO 95.0",
#         "localidad": "PAYSANDU",
#         "departamento": "PAYSANDU",
#         "latitud": -32.335291715861,
#         "longitud": -58.067650659832,
#         "cedula": "66977506",
#         "fecha_nacimiento": "2016-10-11",
#         "fecha_inicio_sintomas": "2024-01-04",
#         "edad": 7,
#         "sexo": "M",
#         "evento": "Dengue",
#         "telefono": "4724 2612",
#         "celular": "093413262",
#         "prestador": "ASSE",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Dolor abdominal intenso y continuo": "S",
#         "Cefalea": "S",
#         "Edemas": "N",
#         "Dolor retroorbitario": "S",
#         "Sangrado de Mucosas": "N",
#         "Nauseas/Vómitos": "N",
#         "Sangrado Grave": "S",
#         "Exantema": "N",
#         "Letargia o irritabilidad": "S",
#         "Mialgias y/o artralgias": "N",
#         "Shock": "S",
#         "Hematocrito (%)": 29,
#         "Plaquetas (/mm3)": 123323,
#         "Leucocitos sangre (/mm3)": 8803
#     },
#     {
#         "nombre": "Julia",
#         "apellido": "Soler",
#         "direccion": "CNO RIGEL 4876.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.7743047897264,
#         "longitud": -56.1544803242491,
#         "cedula": "26923791",
#         "fecha_nacimiento": "1992-11-06",
#         "fecha_inicio_sintomas": "2024-01-08",
#         "edad": 31,
#         "sexo": "F",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "2614 4204",
#         "celular": "098504042",
#         "prestador": "SEGURO AMERICANO",
#         "internado": "N",
#         "tipo_internado": "sin dato",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "Cocos Gram positivos",
#         "Aspecto LCR (citoquímico)": "turbio",
#         "Glucosa LCR (mg/dl)": 8.5,
#         "Proteínas en LCR (mg/dl)": 28.9,
#         "Leucocitos LCR (/mm3)": 3252,
#         "Predominio": "Linfocitos"
#     },
#     {
#         "nombre": "María Belén",
#         "apellido": "Elorza",
#         "direccion": "PARAGUAY 1565.0",
#         "localidad": "MONTEVIDEO",
#         "departamento": "MONTEVIDEO",
#         "latitud": -34.9018373147456,
#         "longitud": -56.1930317362189,
#         "cedula": "24925173",
#         "fecha_nacimiento": "1983-01-21",
#         "fecha_inicio_sintomas": "2024-02-08",
#         "edad": 41,
#         "sexo": "F",
#         "evento": "Dengue",
#         "telefono": "2333 2626",
#         "celular": "094379573",
#         "prestador": "COSEM IAMPP",
#         "internado": "S",
#         "tipo_internado": "CTI",
#         "Fiebre": "S",
#         "Dolor abdominal intenso y continuo": "S",
#         "Cefalea": "S",
#         "Edemas": "N",
#         "Dolor retroorbitario": "N",
#         "Sangrado de Mucosas": "S",
#         "Nauseas/Vómitos": "S",
#         "Sangrado Grave": "N",
#         "Exantema": "S",
#         "Letargia o irritabilidad": "S",
#         "Mialgias y/o artralgias": "S",
#         "Shock": "N",
#         "Hematocrito (%)": 35,
#         "Plaquetas (/mm3)": 971088,
#         "Leucocitos sangre (/mm3)": 6845
#     },
#     {
#         "nombre": "Roxana",
#         "apellido": "Miró",
#         "direccion": "",
#         "localidad": "ARTIGAS",
#         "departamento": "ARTIGAS",
#         "latitud": -30.4093734339368,
#         "longitud": -56.4677466452056,
#         "cedula": "18105600",
#         "fecha_nacimiento": "2013-04-03",
#         "fecha_inicio_sintomas": "2024-05-12",
#         "edad": 11,
#         "sexo": "F",
#         "evento": "Meningitis Bacteriana",
#         "telefono": "4777 3141",
#         "celular": "092091099",
#         "prestador": "ASSE",
#         "internado": "S",
#         "tipo_internado": "CM",
#         "Fiebre": "N",
#         "Convulsión": "S",
#         "Petequias": "S",
#         "Signos de irritación meníngea": "N",
#         "Alteración de conciencia": "N",
#         "Hipopefusión periférica": "N",
#         "Paciente Grave": "N",
#         "Directo LCR": "Cocos Gram positivos",
#         "Aspecto LCR (citoquímico)": "transparente",
#         "Glucosa LCR (mg/dl)": 46.6,
#         "Proteínas en LCR (mg/dl)": 20.5,
#         "Leucocitos LCR (/mm3)": 255,
#         "Predominio": "PMN"
#     }
# ]

# %% [markdown]
# Ahora genero los datos del laboratorio, a partir de 450 de las 500 notificaciones generadas.

# %%
import json
import pandas as pd
import random
from datetime import datetime, timedelta

# Leer el archivo JSON completo si contiene un array de objetos
def leer_json_completo(filepath):
    with open(filepath, 'r', encoding='utf-8') as file:
        try:
            objetos = json.load(file)
        except json.JSONDecodeError as e:
            print(f"Error al decodificar JSON: {e}")
            return []
    return objetos

# Ruta al archivo JSON
archivo_json = 'notificaciones_ficticias.json'

# Leer los objetos JSON del archivo
personas = leer_json_completo(archivo_json)

# Convertir lista de personas a DataFrame
df_personas = pd.DataFrame(personas)

# Seleccionar 450 registros únicos por CI
selected_cis = df_personas['cedula'].unique()
selected_personas = df_personas[df_personas['cedula'].isin(random.sample(list(selected_cis), min(450, len(selected_cis))))]

# Generar DataFrame de laboratorio
laboratorio_data = []

# Separar personas con evento "Dengue" y el resto
dengue_personas = selected_personas[selected_personas['evento'] == 'Dengue']
otros_personas = selected_personas[selected_personas['evento'] != 'Dengue']

# Procesar personas con evento "Dengue" (95% resultados positivos)
for _, persona in dengue_personas.iterrows():
    fecha_muestra = datetime.strptime(persona['fecha_inicio_sintomas'], '%Y-%m-%d') + timedelta(days=5)
    estado = 'finalizado'  # Para asegurar que todos los resultados positivos tengan estado finalizado
    test = random.choice(['serología', 'PCR'])
    resultado = 'positivo' if random.random() < 0.95 else 'negativo'
    
    laboratorio_data.append({
        'cedula': persona['cedula'],
        'nombre': persona['nombre'],
        'apellido': persona['apellido'],
        'evento': persona['evento'],
        'fecha_muestra': fecha_muestra.strftime('%Y-%m-%d'),
        'estado': estado,
        'test': test,
        'resultado': resultado
    })

# Procesar el resto de las personas (50% resultados positivos)
for _, persona in otros_personas.iterrows():
    fecha_muestra = datetime.strptime(persona['fecha_inicio_sintomas'], '%Y-%m-%d') + timedelta(days=5)
    estado = random.choice(['en tránsito', 'recibido', 'en proceso', 'finalizado'])
    
    # Si el estado no es 'finalizado', el resultado debe estar vacío
    if estado == 'finalizado':
        resultado = 'positivo' if random.random() < 0.50 else 'negativo'
    else:
        resultado = None
    
    # Si el resultado es positivo, asegurarse de que el estado sea 'finalizado'
    if resultado == 'positivo':
        estado = 'finalizado'
    
    laboratorio_data.append({
        'cedula': persona['cedula'],
        'nombre': persona['nombre'],
        'apellido': persona['apellido'],
        'evento': persona['evento'],
        'fecha_muestra': fecha_muestra.strftime('%Y-%m-%d'),
        'estado': estado,
        'test': random.choice(['serología', 'PCR']),
        'resultado': resultado
    })

# Convertir lista a DataFrame
df_laboratorio = pd.DataFrame(laboratorio_data)

# Guardar el DataFrame de laboratorio en un archivo CSV con las columnas deseadas
df_laboratorio.to_csv('lab-data.csv', columns=['cedula', 'nombre', 'apellido', 'evento', 'fecha_muestra', 'estado', 'test', 'resultado'], index=False)

# %%
display(df_laboratorio)
# Out:
#        cedula    nombre apellido                 evento fecha_muestra  \
# 0    11654303    Pepito     Malo                 Dengue    2024-03-14
# 1    99349801     Lidia  Canales                 Dengue    2024-01-24
# 2    10431065    Eloísa  Salazar                 Dengue    2024-07-06
# 3    40582816    Carlos    Peñas                 Dengue    2024-03-31
# 4    57631591      Raúl    Comas                 Dengue    2024-05-19
# ..        ...       ...      ...                    ...           ...
# 445  87598527     Ruben  Cervera       Meningitis Viral    2024-03-04
# 446  15111654      Manu  Sevilla          Leptospirosis    2024-08-05
# 447  78659790  Brunilda  Alvarez       Meningitis Viral    2024-05-26
# 448  26923791     Julia    Soler  Meningitis Bacteriana    2024-01-13
# 449  18105600    Roxana     Miró  Meningitis Bacteriana    2024-05-17
#
#           estado       test resultado
# 0     finalizado        PCR  positivo
# 1     finalizado        PCR  positivo
# 2     finalizado  serología  positivo
# 3     finalizado        PCR  positivo
# 4     finalizado  serología  positivo
# ..           ...        ...       ...
# 445   en proceso  serología      None
# 446   en proceso        PCR      None
# 447     recibido  serología      None
# 448   en proceso  serología      None
# 449  en tránsito        PCR      None
#
# [450 rows x 8 columns]

# %% [markdown]
# Ahora genero 5 años de datos de leptospirosis para calcular el corredor endémico

# %%
import json
import random
from faker import Faker
from datetime import datetime, timedelta
from decimal import Decimal

# Inicializar Faker
fake = Faker('es_ES')  # Faker para generar nombres y apellidos en español

# Función para convertir Decimal a float en un diccionario
def convertir_decimal_a_float(d):
    if isinstance(d, dict):
        return {k: convertir_decimal_a_float(v) for k, v in d.items()}
    elif isinstance(d, list):
        return [convertir_decimal_a_float(i) for i in d]
    elif isinstance(d, Decimal):
        return float(d)
    else:
        return d

# Función para calcular la semana epidemiológica (SE) a partir de la fecha de inicio de síntomas
def calcular_se(fecha_inicio, ae):
    fechas_rango = {
        2019: (datetime(2018, 12, 31), datetime(2019, 12, 28)),
        2020: (datetime(2019, 12, 29), datetime(2020, 12, 27)),
        2021: (datetime(2020, 12, 28), datetime(2021, 12, 26)),
        2022: (datetime(2021, 12, 27), datetime(2022, 12, 31)),
        2023: (datetime(2022, 12, 31), datetime(2023, 12, 30)),
    }
    
    start_date, end_date = fechas_rango[ae]
    days_diff = (fecha_inicio - start_date).days
    se = (days_diff // 7) + 1
    
    if ae == 2020 and se > 53:
        se = 53
    
    return se

# Generar datos ficticios de leptospirosis para un año epidemiológico específico
def generar_datos_leptospirosis(ae):
    leptospirosis_data = []
    
    fechas_rango = {
        2019: (datetime(2018, 12, 31), datetime(2019, 12, 28)),
        2020: (datetime(2019, 12, 29), datetime(2020, 12, 27)),
        2021: (datetime(2020, 12, 28), datetime(2021, 12, 26)),
        2022: (datetime(2021, 12, 27), datetime(2022, 12, 31)),
        2023: (datetime(2022, 12, 31), datetime(2023, 12, 30)),
    }
    
    start_date, end_date = fechas_rango[ae]
    num_notificaciones = random.randint(100, 130)
    
    for _ in range(num_notificaciones):
        fecha_inicio_sintomas = start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
        se = calcular_se(fecha_inicio_sintomas, ae)
        fecha_muestra = fecha_inicio_sintomas + timedelta(days=5)
        
        leptospirosis_data.append({
            'nombre': fake.first_name(),
            'apellido': fake.last_name(),
            'direccion': f"{fake.street_name()} {random.randint(1, 100)}",
            'localidad': fake.city(),
            'departamento': fake.state(),
            'latitud': fake.latitude(),
            'longitud': fake.longitude(),
            'cedula': fake.ssn(),
            'fecha_nacimiento': fake.date_of_birth(minimum_age=0, maximum_age=90).strftime('%Y-%m-%d'),
            'fecha_inicio_sintomas': fecha_inicio_sintomas.strftime('%Y-%m-%d'),
            'edad': random.randint(0, 90),
            'sexo': random.choice(['M', 'F']),
            'evento': 'Leptospirosis',
            'telefono': fake.phone_number(),
            'celular': f"09{random.randint(1000000, 9999999)}",
            'prestador': fake.company(),
            'internado': random.choice(['S', 'N']),
            'tipo_internado': random.choice(['CTI', 'CM']) if random.choice(['S', 'N']) == 'S' else 'sin dato',
            'Fiebre': random.choice(['S', 'N']),
            'Cefalea': random.choice(['S', 'N']),
            'Síndrome hemorragíparo': random.choice(['S', 'N']),
            'Mialgias y/o artralgias': random.choice(['S', 'N']),
            'Compromiso renal': random.choice(['S', 'N']),
            'Compromiso hepático': random.choice(['S', 'N']),
            'Sintomatología digestiva': random.choice(['S', 'N']),
            'Ictericia': random.choice(['S', 'N']),
            'Hiperemia conjuntival': random.choice(['S', 'N']),
            'Neumonia/Neumonitis': random.choice(['S', 'N']),
            'Lesiones de piel': random.choice(['S', 'N']),
            'Hematocrito (%)': random.randint(30, 50),
            'Plaquetas (/mm3)': random.randint(100000, 1000000),
            'Leucocitos sangre (/mm3)': random.randint(10000, 30000),
            'Función hepática BT (mg/dl)': round(random.uniform(1.0, 20.0), 1),
            'Función hepática TGO (UI/l)': round(random.uniform(10.0, 100.0), 1),
            'Función hepática LDH (mg/dl)': random.randint(100, 1000),
            'Función hepática TGP (UI/l)': round(random.uniform(10.0, 100.0), 1),
            'Función renal azoemia (mg/dl)': round(random.uniform(10.0, 100.0), 1),
            'Función renal creatinemia (mg/dl)': round(random.uniform(0.5, 10.0), 1),
            'AE': ae,
            'SE': se,
            'estado': 'confirmado',
            'resultados_laboratorio': {
                'cedula': fake.ssn(),
                'nombre': fake.first_name(),
                'apellido': fake.last_name(),
                'evento': 'Leptospirosis',
                'fecha_muestra': fecha_muestra.strftime('%Y-%m-%d'),
                'estado': 'finalizado',
                'test': 'PCR',
                'resultado': 'positivo'
            }
        })
    
    return leptospirosis_data

# Generar datos para los años epidemiológicos entre 2019 y 2023
leptospirosis_data_total = []

for ae in range(2019, 2024):
    leptospirosis_data_total.extend(generar_datos_leptospirosis(ae))

# Convertir Decimals a floats
leptospirosis_data_total = convertir_decimal_a_float(leptospirosis_data_total)

# Guardar los datos en un archivo JSON
with open('leptospirosis_data.json', 'w', encoding='utf-8') as file:
    json.dump(leptospirosis_data_total, file, ensure_ascii=False, indent=4)

print("Datos de leptospirosis guardados en 'leptospirosis_data.json'.")
# Out:
# Datos de leptospirosis guardados en 'leptospirosis_data.json'.

# %%
import json

# Ruta al archivo JSON
archivo_json = 'leptospirosis_data.json'

# Cargar el archivo JSON
with open(archivo_json, 'r', encoding='utf-8') as archivo:
    datos = json.load(archivo)

# Mostrar los datos en un formato legible
for registro in datos:
    print(json.dumps(registro, indent=4, ensure_ascii=False))
# Out:
# {
#     "nombre": "Zaira",
#     "apellido": "Pascual",
#     "direccion": "Avenida Anna Vidal 71",
#     "localidad": "León",
#     "departamento": "Huelva",
#     "latitud": 53.0158835,
#     "longitud": 57.081236,
#     "cedula": "052-19-1434",
#     "fecha_nacimiento": "1943-12-10",
#     "fecha_inicio_sintomas": "2019-08-20",
#     "edad": 41,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 947 446 068",
#     "celular": "097026194",
#     "prestador": "Berrocal y asociados S.Coop.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 43,
#     "Plaquetas (/mm3)": 938524,
#     "Leucocitos sangre (/mm3)": 10554,
#     "Función hepática BT (mg/dl)": 3.5,
#     "Función hepática TGO (UI/l)": 68.6,
#     "Función hepática LDH (mg/dl)": 152,
#     "Función hepática TGP (UI/l)": 42.9,
#     "Función renal azoemia (mg/dl)": 93.3,
#     "Función renal creatinemia (mg/dl)": 7.9,
#     "AE": 2019,
#     "SE": 34,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "631-27-4859",
#         "nombre": "José Manuel",
#         "apellido": "Llamas",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-08-25",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Casandra",
#     "apellido": "Urrutia",
#     "direccion": "Pasadizo de Primitivo Mateos 29",
#     "localidad": "Córdoba",
#     "departamento": "Barcelona",
#     "latitud": 58.058085,
#     "longitud": 157.449665,
#     "cedula": "025-23-3261",
#     "fecha_nacimiento": "1948-04-14",
#     "fecha_inicio_sintomas": "2019-08-12",
#     "edad": 61,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34845268524",
#     "celular": "092672454",
#     "prestador": "Adoración Vigil Beltran S.L.N.E",
#     "internado": "N",
#     "tipo_internado": "sin dato",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 42,
#     "Plaquetas (/mm3)": 573556,
#     "Leucocitos sangre (/mm3)": 28297,
#     "Función hepática BT (mg/dl)": 10.6,
#     "Función hepática TGO (UI/l)": 58.2,
#     "Función hepática LDH (mg/dl)": 587,
#     "Función hepática TGP (UI/l)": 18.1,
#     "Función renal azoemia (mg/dl)": 35.3,
#     "Función renal creatinemia (mg/dl)": 8.8,
#     "AE": 2019,
#     "SE": 33,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "337-58-5751",
#         "nombre": "José Antonio",
#         "apellido": "Plaza",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-08-17",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Bernardino",
#     "apellido": "Gallart",
#     "direccion": "Urbanización de Coral Jover 30",
#     "localidad": "Cáceres",
#     "departamento": "Valladolid",
#     "latitud": -18.1713505,
#     "longitud": 27.895835,
#     "cedula": "040-51-1427",
#     "fecha_nacimiento": "1970-07-04",
#     "fecha_inicio_sintomas": "2019-07-30",
#     "edad": 22,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34887242940",
#     "celular": "095615586",
#     "prestador": "Gallart y Puente S.A.",
#     "internado": "S",
#     "tipo_internado": "CTI",
#     "Fiebre": "S",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 42,
#     "Plaquetas (/mm3)": 932454,
#     "Leucocitos sangre (/mm3)": 15559,
#     "Función hepática BT (mg/dl)": 4.4,
#     "Función hepática TGO (UI/l)": 25.0,
#     "Función hepática LDH (mg/dl)": 906,
#     "Función hepática TGP (UI/l)": 11.6,
#     "Función renal azoemia (mg/dl)": 56.1,
#     "Función renal creatinemia (mg/dl)": 2.2,
#     "AE": 2019,
#     "SE": 31,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "029-02-9867",
#         "nombre": "Tadeo",
#         "apellido": "Amo",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-08-04",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Morena",
#     "apellido": "Oller",
#     "direccion": "Camino de Ruperta Milla 76",
#     "localidad": "Cantabria",
#     "departamento": "Lugo",
#     "latitud": 10.877692,
#     "longitud": 96.634684,
#     "cedula": "058-20-0508",
#     "fecha_nacimiento": "1991-01-05",
#     "fecha_inicio_sintomas": "2019-04-09",
#     "edad": 28,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34980453608",
#     "celular": "093697752",
#     "prestador": "Finanzas del Norte S.Com.",
#     "internado": "N",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 33,
#     "Plaquetas (/mm3)": 997433,
#     "Leucocitos sangre (/mm3)": 11300,
#     "Función hepática BT (mg/dl)": 3.2,
#     "Función hepática TGO (UI/l)": 24.1,
#     "Función hepática LDH (mg/dl)": 932,
#     "Función hepática TGP (UI/l)": 82.4,
#     "Función renal azoemia (mg/dl)": 96.9,
#     "Función renal creatinemia (mg/dl)": 1.1,
#     "AE": 2019,
#     "SE": 15,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "024-20-7814",
#         "nombre": "Nicolás",
#         "apellido": "Menéndez",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-04-14",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Esmeralda",
#     "apellido": "Noguera",
#     "direccion": "Pasadizo Florentina Iñiguez 54",
#     "localidad": "La Coruña",
#     "departamento": "Palencia",
#     "latitud": 18.2500145,
#     "longitud": 176.579221,
#     "cedula": "247-65-3714",
#     "fecha_nacimiento": "1946-07-02",
#     "fecha_inicio_sintomas": "2019-09-14",
#     "edad": 2,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34986 747 476",
#     "celular": "097165145",
#     "prestador": "Ariño & Asociados S.L.N.E",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 32,
#     "Plaquetas (/mm3)": 714543,
#     "Leucocitos sangre (/mm3)": 21322,
#     "Función hepática BT (mg/dl)": 2.1,
#     "Función hepática TGO (UI/l)": 91.0,
#     "Función hepática LDH (mg/dl)": 722,
#     "Función hepática TGP (UI/l)": 22.9,
#     "Función renal azoemia (mg/dl)": 33.2,
#     "Función renal creatinemia (mg/dl)": 0.9,
#     "AE": 2019,
#     "SE": 37,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "799-00-2924",
#         "nombre": "Leyre",
#         "apellido": "Molins",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-09-19",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Victor Manuel",
#     "apellido": "Mayo",
#     "direccion": "Acceso de Carmela Pombo 75",
#     "localidad": "Huesca",
#     "departamento": "Pontevedra",
#     "latitud": 0.598048,
#     "longitud": 45.177079,
#     "cedula": "959-35-1560",
#     "fecha_nacimiento": "1978-07-12",
#     "fecha_inicio_sintomas": "2019-11-07",
#     "edad": 64,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34 944 754 625",
#     "celular": "097105808",
#     "prestador": "Fábrica Arenas y asociados S.L.N.E",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 32,
#     "Plaquetas (/mm3)": 895342,
#     "Leucocitos sangre (/mm3)": 28200,
#     "Función hepática BT (mg/dl)": 3.8,
#     "Función hepática TGO (UI/l)": 80.6,
#     "Función hepática LDH (mg/dl)": 499,
#     "Función hepática TGP (UI/l)": 21.6,
#     "Función renal azoemia (mg/dl)": 56.4,
#     "Función renal creatinemia (mg/dl)": 6.6,
#     "AE": 2019,
#     "SE": 45,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "634-66-5256",
#         "nombre": "Amparo",
#         "apellido": "Ribes",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-11-12",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Coral",
#     "apellido": "Arroyo",
#     "direccion": "Acceso Antonia Amo 17",
#     "localidad": "Asturias",
#     "departamento": "Huelva",
#     "latitud": -82.23213,
#     "longitud": 129.844544,
#     "cedula": "625-22-0011",
#     "fecha_nacimiento": "1965-05-10",
#     "fecha_inicio_sintomas": "2019-08-08",
#     "edad": 56,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34942 39 01 26",
#     "celular": "097355357",
#     "prestador": "Tecnologías del Noroeste S.Coop.",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 35,
#     "Plaquetas (/mm3)": 614078,
#     "Leucocitos sangre (/mm3)": 25771,
#     "Función hepática BT (mg/dl)": 4.9,
#     "Función hepática TGO (UI/l)": 19.2,
#     "Función hepática LDH (mg/dl)": 794,
#     "Función hepática TGP (UI/l)": 54.3,
#     "Función renal azoemia (mg/dl)": 74.7,
#     "Función renal creatinemia (mg/dl)": 0.5,
#     "AE": 2019,
#     "SE": 32,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "503-71-3836",
#         "nombre": "Ester",
#         "apellido": "Coca",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-08-13",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Rufina",
#     "apellido": "Alcántara",
#     "direccion": "Calle Alejandra Córdoba 23",
#     "localidad": "Jaén",
#     "departamento": "Badajoz",
#     "latitud": 9.503047,
#     "longitud": -8.093269,
#     "cedula": "850-81-6617",
#     "fecha_nacimiento": "2021-04-10",
#     "fecha_inicio_sintomas": "2019-09-18",
#     "edad": 71,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34980586927",
#     "celular": "098336304",
#     "prestador": "Familia Camacho S.A.",
#     "internado": "N",
#     "tipo_internado": "CM",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 46,
#     "Plaquetas (/mm3)": 606997,
#     "Leucocitos sangre (/mm3)": 12499,
#     "Función hepática BT (mg/dl)": 9.3,
#     "Función hepática TGO (UI/l)": 71.8,
#     "Función hepática LDH (mg/dl)": 904,
#     "Función hepática TGP (UI/l)": 13.0,
#     "Función renal azoemia (mg/dl)": 50.9,
#     "Función renal creatinemia (mg/dl)": 4.4,
#     "AE": 2019,
#     "SE": 38,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "929-28-6982",
#         "nombre": "Bernarda",
#         "apellido": "Menendez",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-09-23",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Purificación",
#     "apellido": "Luna",
#     "direccion": "Plaza de Olga Riba 64",
#     "localidad": "Huelva",
#     "departamento": "Teruel",
#     "latitud": -62.216491,
#     "longitud": 101.914143,
#     "cedula": "491-04-9975",
#     "fecha_nacimiento": "1936-11-03",
#     "fecha_inicio_sintomas": "2019-10-18",
#     "edad": 83,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34963 264 871",
#     "celular": "092927301",
#     "prestador": "Jesusa Ferrando Casas S.L.U.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 43,
#     "Plaquetas (/mm3)": 463294,
#     "Leucocitos sangre (/mm3)": 19172,
#     "Función hepática BT (mg/dl)": 19.2,
#     "Función hepática TGO (UI/l)": 39.1,
#     "Función hepática LDH (mg/dl)": 912,
#     "Función hepática TGP (UI/l)": 70.1,
#     "Función renal azoemia (mg/dl)": 20.8,
#     "Función renal creatinemia (mg/dl)": 6.7,
#     "AE": 2019,
#     "SE": 42,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "721-54-1396",
#         "nombre": "Ángeles",
#         "apellido": "Huertas",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-10-23",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Rogelio",
#     "apellido": "Sacristán",
#     "direccion": "Pasadizo Adán Pallarès 23",
#     "localidad": "Zamora",
#     "departamento": "Huesca",
#     "latitud": 20.0915965,
#     "longitud": -61.986097,
#     "cedula": "643-49-0282",
#     "fecha_nacimiento": "2010-02-03",
#     "fecha_inicio_sintomas": "2019-06-24",
#     "edad": 58,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34987 13 56 14",
#     "celular": "093810184",
#     "prestador": "Vilalta y Briones S.L.",
#     "internado": "N",
#     "tipo_internado": "sin dato",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 39,
#     "Plaquetas (/mm3)": 616135,
#     "Leucocitos sangre (/mm3)": 15609,
#     "Función hepática BT (mg/dl)": 7.4,
#     "Función hepática TGO (UI/l)": 30.3,
#     "Función hepática LDH (mg/dl)": 167,
#     "Función hepática TGP (UI/l)": 66.3,
#     "Función renal azoemia (mg/dl)": 14.1,
#     "Función renal creatinemia (mg/dl)": 1.0,
#     "AE": 2019,
#     "SE": 26,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "341-22-2148",
#         "nombre": "Ruben",
#         "apellido": "Carballo",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-06-29",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Blas",
#     "apellido": "Roma",
#     "direccion": "Acceso Aitor Vallejo 28",
#     "localidad": "Girona",
#     "departamento": "Málaga",
#     "latitud": 28.599076,
#     "longitud": 53.461938,
#     "cedula": "703-63-6760",
#     "fecha_nacimiento": "1989-04-14",
#     "fecha_inicio_sintomas": "2019-09-01",
#     "edad": 36,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34884 426 810",
#     "celular": "098883168",
#     "prestador": "Banca Privada del Norte S.L.L.",
#     "internado": "N",
#     "tipo_internado": "sin dato",
#     "Fiebre": "S",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 47,
#     "Plaquetas (/mm3)": 840246,
#     "Leucocitos sangre (/mm3)": 22434,
#     "Función hepática BT (mg/dl)": 2.1,
#     "Función hepática TGO (UI/l)": 50.8,
#     "Función hepática LDH (mg/dl)": 353,
#     "Función hepática TGP (UI/l)": 83.8,
#     "Función renal azoemia (mg/dl)": 24.4,
#     "Función renal creatinemia (mg/dl)": 5.5,
#     "AE": 2019,
#     "SE": 35,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "783-23-0411",
#         "nombre": "Elba",
#         "apellido": "Marquez",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-09-06",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Juan Francisco",
#     "apellido": "Ferrero",
#     "direccion": "Via de Alicia Mascaró 20",
#     "localidad": "Salamanca",
#     "departamento": "Las Palmas",
#     "latitud": -79.206357,
#     "longitud": 31.479129,
#     "cedula": "984-15-1999",
#     "fecha_nacimiento": "2011-08-03",
#     "fecha_inicio_sintomas": "2019-05-27",
#     "edad": 25,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34 883 53 13 43",
#     "celular": "094687166",
#     "prestador": "Marcos & Asociados S.L.N.E",
#     "internado": "N",
#     "tipo_internado": "CM",
#     "Fiebre": "S",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 38,
#     "Plaquetas (/mm3)": 571429,
#     "Leucocitos sangre (/mm3)": 10143,
#     "Función hepática BT (mg/dl)": 8.4,
#     "Función hepática TGO (UI/l)": 14.6,
#     "Función hepática LDH (mg/dl)": 278,
#     "Función hepática TGP (UI/l)": 74.5,
#     "Función renal azoemia (mg/dl)": 48.6,
#     "Función renal creatinemia (mg/dl)": 4.0,
#     "AE": 2019,
#     "SE": 22,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "111-24-9873",
#         "nombre": "Trini",
#         "apellido": "Navas",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-06-01",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Azeneth",
#     "apellido": "Herranz",
#     "direccion": "Plaza Santiago Real 62",
#     "localidad": "Sevilla",
#     "departamento": "Guadalajara",
#     "latitud": 7.895492,
#     "longitud": -124.888596,
#     "cedula": "232-54-7692",
#     "fecha_nacimiento": "1942-04-26",
#     "fecha_inicio_sintomas": "2019-01-02",
#     "edad": 19,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 955854495",
#     "celular": "091527677",
#     "prestador": "Hermanos Segura S.L.",
#     "internado": "S",
#     "tipo_internado": "CTI",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 50,
#     "Plaquetas (/mm3)": 349216,
#     "Leucocitos sangre (/mm3)": 24549,
#     "Función hepática BT (mg/dl)": 10.6,
#     "Función hepática TGO (UI/l)": 79.9,
#     "Función hepática LDH (mg/dl)": 189,
#     "Función hepática TGP (UI/l)": 13.7,
#     "Función renal azoemia (mg/dl)": 17.3,
#     "Función renal creatinemia (mg/dl)": 7.7,
#     "AE": 2019,
#     "SE": 1,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "843-43-4405",
#         "nombre": "Rodolfo",
#         "apellido": "Valenciano",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-01-07",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Filomena",
#     "apellido": "Pineda",
#     "direccion": "Plaza de Crescencia Cañizares 71",
#     "localidad": "Huesca",
#     "departamento": "Zamora",
#     "latitud": -33.3360745,
#     "longitud": 172.849129,
#     "cedula": "181-78-0407",
#     "fecha_nacimiento": "1968-05-15",
#     "fecha_inicio_sintomas": "2019-08-22",
#     "edad": 78,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 831945796",
#     "celular": "096991873",
#     "prestador": "Pedro y Tejada S.Com.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 40,
#     "Plaquetas (/mm3)": 635321,
#     "Leucocitos sangre (/mm3)": 25075,
#     "Función hepática BT (mg/dl)": 1.9,
#     "Función hepática TGO (UI/l)": 88.6,
#     "Función hepática LDH (mg/dl)": 898,
#     "Función hepática TGP (UI/l)": 98.3,
#     "Función renal azoemia (mg/dl)": 88.6,
#     "Función renal creatinemia (mg/dl)": 3.8,
#     "AE": 2019,
#     "SE": 34,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "778-46-8470",
#         "nombre": "Ernesto",
#         "apellido": "Santiago",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-08-27",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Dani",
#     "apellido": "Tejada",
#     "direccion": "Via de Luisina Benet 51",
#     "localidad": "Girona",
#     "departamento": "Ceuta",
#     "latitud": -32.735383,
#     "longitud": -59.687216,
#     "cedula": "785-91-4361",
#     "fecha_nacimiento": "1944-11-24",
#     "fecha_inicio_sintomas": "2019-01-17",
#     "edad": 36,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 983718388",
#     "celular": "098081410",
#     "prestador": "Aurelia Vidal Luz S.A.U",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "S",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 47,
#     "Plaquetas (/mm3)": 761688,
#     "Leucocitos sangre (/mm3)": 28357,
#     "Función hepática BT (mg/dl)": 12.7,
#     "Función hepática TGO (UI/l)": 82.7,
#     "Función hepática LDH (mg/dl)": 954,
#     "Función hepática TGP (UI/l)": 47.1,
#     "Función renal azoemia (mg/dl)": 23.3,
#     "Función renal creatinemia (mg/dl)": 2.5,
#     "AE": 2019,
#     "SE": 3,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "280-95-5526",
#         "nombre": "Óscar",
#         "apellido": "Varela",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-01-22",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Elvira",
#     "apellido": "Rius",
#     "direccion": "Cañada Adriana Arregui 84",
#     "localidad": "Ciudad",
#     "departamento": "Segovia",
#     "latitud": 15.2447105,
#     "longitud": 34.145101,
#     "cedula": "310-60-6373",
#     "fecha_nacimiento": "2012-05-23",
#     "fecha_inicio_sintomas": "2019-12-17",
#     "edad": 7,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34873074339",
#     "celular": "094063000",
#     "prestador": "Tecnologías ZZA S.L.N.E",
#     "internado": "N",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 31,
#     "Plaquetas (/mm3)": 474612,
#     "Leucocitos sangre (/mm3)": 15817,
#     "Función hepática BT (mg/dl)": 12.9,
#     "Función hepática TGO (UI/l)": 58.9,
#     "Función hepática LDH (mg/dl)": 677,
#     "Función hepática TGP (UI/l)": 66.2,
#     "Función renal azoemia (mg/dl)": 19.9,
#     "Función renal creatinemia (mg/dl)": 7.7,
#     "AE": 2019,
#     "SE": 51,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "210-06-1880",
#         "nombre": "Cristina",
#         "apellido": "Guardia",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-12-22",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Felisa",
#     "apellido": "Carnero",
#     "direccion": "Avenida de Violeta Madrigal 8",
#     "localidad": "Córdoba",
#     "departamento": "La Rioja",
#     "latitud": -61.375076,
#     "longitud": 49.46453,
#     "cedula": "814-48-9166",
#     "fecha_nacimiento": "1961-07-16",
#     "fecha_inicio_sintomas": "2019-11-13",
#     "edad": 81,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34942 723 187",
#     "celular": "098159527",
#     "prestador": "Dan Castelló Lluch S.A.",
#     "internado": "N",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 48,
#     "Plaquetas (/mm3)": 654080,
#     "Leucocitos sangre (/mm3)": 27770,
#     "Función hepática BT (mg/dl)": 5.2,
#     "Función hepática TGO (UI/l)": 92.3,
#     "Función hepática LDH (mg/dl)": 365,
#     "Función hepática TGP (UI/l)": 19.8,
#     "Función renal azoemia (mg/dl)": 17.2,
#     "Función renal creatinemia (mg/dl)": 6.1,
#     "AE": 2019,
#     "SE": 46,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "692-47-9809",
#         "nombre": "Azeneth",
#         "apellido": "Catalá",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-11-18",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Trinidad",
#     "apellido": "Comas",
#     "direccion": "Alameda de Ciríaco Morata 78",
#     "localidad": "Toledo",
#     "departamento": "Málaga",
#     "latitud": 60.540894,
#     "longitud": 143.269748,
#     "cedula": "165-46-0925",
#     "fecha_nacimiento": "1977-06-06",
#     "fecha_inicio_sintomas": "2019-11-17",
#     "edad": 22,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34849 701 978",
#     "celular": "093988124",
#     "prestador": "Familia Ropero S.Coop.",
#     "internado": "S",
#     "tipo_internado": "CM",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 41,
#     "Plaquetas (/mm3)": 261472,
#     "Leucocitos sangre (/mm3)": 10127,
#     "Función hepática BT (mg/dl)": 6.7,
#     "Función hepática TGO (UI/l)": 92.7,
#     "Función hepática LDH (mg/dl)": 213,
#     "Función hepática TGP (UI/l)": 12.0,
#     "Función renal azoemia (mg/dl)": 42.3,
#     "Función renal creatinemia (mg/dl)": 0.8,
#     "AE": 2019,
#     "SE": 46,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "440-00-8337",
#         "nombre": "Amando",
#         "apellido": "Lozano",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-11-22",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Arsenio",
#     "apellido": "Ballester",
#     "direccion": "Pasaje de Manuelita Tomé 76",
#     "localidad": "Zaragoza",
#     "departamento": "Cuenca",
#     "latitud": -49.1566975,
#     "longitud": -158.682212,
#     "cedula": "573-15-8760",
#     "fecha_nacimiento": "1975-09-22",
#     "fecha_inicio_sintomas": "2019-01-19",
#     "edad": 6,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34859588729",
#     "celular": "097593231",
#     "prestador": "Jose Ramón Barba Arteaga S.Coop.",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "S",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 30,
#     "Plaquetas (/mm3)": 623498,
#     "Leucocitos sangre (/mm3)": 23347,
#     "Función hepática BT (mg/dl)": 13.7,
#     "Función hepática TGO (UI/l)": 39.6,
#     "Función hepática LDH (mg/dl)": 361,
#     "Función hepática TGP (UI/l)": 40.5,
#     "Función renal azoemia (mg/dl)": 42.9,
#     "Función renal creatinemia (mg/dl)": 4.2,
#     "AE": 2019,
#     "SE": 3,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "138-19-3068",
#         "nombre": "Angelino",
#         "apellido": "Castellanos",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-01-24",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Jafet",
#     "apellido": "Mateo",
#     "direccion": "Urbanización de María Pilar Feliu 68",
#     "localidad": "Ávila",
#     "departamento": "Almería",
#     "latitud": -84.9698985,
#     "longitud": 24.405195,
#     "cedula": "678-34-7140",
#     "fecha_nacimiento": "1949-10-09",
#     "fecha_inicio_sintomas": "2019-12-28",
#     "edad": 82,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 923 25 14 81",
#     "celular": "098383522",
#     "prestador": "Soluciones Segovia S.C.P",
#     "internado": "S",
#     "tipo_internado": "CM",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 40,
#     "Plaquetas (/mm3)": 682068,
#     "Leucocitos sangre (/mm3)": 25940,
#     "Función hepática BT (mg/dl)": 19.0,
#     "Función hepática TGO (UI/l)": 52.6,
#     "Función hepática LDH (mg/dl)": 345,
#     "Función hepática TGP (UI/l)": 93.9,
#     "Función renal azoemia (mg/dl)": 73.1,
#     "Función renal creatinemia (mg/dl)": 6.5,
#     "AE": 2019,
#     "SE": 52,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "524-25-2137",
#         "nombre": "Débora",
#         "apellido": "Córdoba",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2020-01-02",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Heraclio",
#     "apellido": "Azorin",
#     "direccion": "Avenida de Gerardo Alcázar 72",
#     "localidad": "Melilla",
#     "departamento": "Álava",
#     "latitud": 68.9145825,
#     "longitud": 31.804571,
#     "cedula": "575-99-2666",
#     "fecha_nacimiento": "1945-12-12",
#     "fecha_inicio_sintomas": "2019-07-18",
#     "edad": 19,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34886467464",
#     "celular": "093375232",
#     "prestador": "Soluciones Arévalo y asociados S.C.P",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 30,
#     "Plaquetas (/mm3)": 743708,
#     "Leucocitos sangre (/mm3)": 27506,
#     "Función hepática BT (mg/dl)": 4.2,
#     "Función hepática TGO (UI/l)": 82.9,
#     "Función hepática LDH (mg/dl)": 532,
#     "Función hepática TGP (UI/l)": 75.2,
#     "Función renal azoemia (mg/dl)": 28.3,
#     "Función renal creatinemia (mg/dl)": 2.9,
#     "AE": 2019,
#     "SE": 29,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "898-78-2791",
#         "nombre": "Amílcar",
#         "apellido": "Franch",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-07-23",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Florencio",
#     "apellido": "Roura",
#     "direccion": "Paseo de Marcio Bonet 87",
#     "localidad": "Palencia",
#     "departamento": "Guipúzcoa",
#     "latitud": -60.2371075,
#     "longitud": -47.915806,
#     "cedula": "939-65-5750",
#     "fecha_nacimiento": "1990-11-21",
#     "fecha_inicio_sintomas": "2019-11-13",
#     "edad": 5,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34 882 411 900",
#     "celular": "098425212",
#     "prestador": "Perlita Roselló Arévalo S.A.D",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 47,
#     "Plaquetas (/mm3)": 757155,
#     "Leucocitos sangre (/mm3)": 26264,
#     "Función hepática BT (mg/dl)": 10.2,
#     "Función hepática TGO (UI/l)": 77.4,
#     "Función hepática LDH (mg/dl)": 553,
#     "Función hepática TGP (UI/l)": 45.7,
#     "Función renal azoemia (mg/dl)": 74.9,
#     "Función renal creatinemia (mg/dl)": 4.5,
#     "AE": 2019,
#     "SE": 46,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "000-32-0284",
#         "nombre": "Andrés",
#         "apellido": "Blanco",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-11-18",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Elvira",
#     "apellido": "Jaume",
#     "direccion": "Urbanización de Esperanza Sanmiguel 84",
#     "localidad": "Valencia",
#     "departamento": "Madrid",
#     "latitud": 88.0181855,
#     "longitud": 0.721253,
#     "cedula": "157-71-1314",
#     "fecha_nacimiento": "1989-03-29",
#     "fecha_inicio_sintomas": "2019-01-02",
#     "edad": 81,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 943649483",
#     "celular": "093085961",
#     "prestador": "Clarisa Cobos Cañete S.A.",
#     "internado": "S",
#     "tipo_internado": "CTI",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 44,
#     "Plaquetas (/mm3)": 871237,
#     "Leucocitos sangre (/mm3)": 20828,
#     "Función hepática BT (mg/dl)": 9.4,
#     "Función hepática TGO (UI/l)": 31.7,
#     "Función hepática LDH (mg/dl)": 444,
#     "Función hepática TGP (UI/l)": 57.6,
#     "Función renal azoemia (mg/dl)": 53.8,
#     "Función renal creatinemia (mg/dl)": 3.9,
#     "AE": 2019,
#     "SE": 1,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "654-62-9538",
#         "nombre": "Venceslás",
#         "apellido": "Amo",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-01-07",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Guiomar",
#     "apellido": "Llanos",
#     "direccion": "Paseo Brígida Salgado 1",
#     "localidad": "Madrid",
#     "departamento": "Ceuta",
#     "latitud": 44.7229385,
#     "longitud": 157.85971,
#     "cedula": "134-81-2015",
#     "fecha_nacimiento": "1974-10-03",
#     "fecha_inicio_sintomas": "2019-09-03",
#     "edad": 58,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34984651141",
#     "celular": "092836422",
#     "prestador": "Fábrica JNOE S.L.N.E",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 39,
#     "Plaquetas (/mm3)": 385139,
#     "Leucocitos sangre (/mm3)": 22158,
#     "Función hepática BT (mg/dl)": 17.3,
#     "Función hepática TGO (UI/l)": 27.5,
#     "Función hepática LDH (mg/dl)": 790,
#     "Función hepática TGP (UI/l)": 10.8,
#     "Función renal azoemia (mg/dl)": 78.8,
#     "Función renal creatinemia (mg/dl)": 3.0,
#     "AE": 2019,
#     "SE": 36,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "374-14-5049",
#         "nombre": "Sebastián",
#         "apellido": "Peralta",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-09-08",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Anastasio",
#     "apellido": "Berenguer",
#     "direccion": "Avenida Reyes Casas 30",
#     "localidad": "Granada",
#     "departamento": "Murcia",
#     "latitud": -36.514404,
#     "longitud": 155.743566,
#     "cedula": "546-62-6629",
#     "fecha_nacimiento": "1993-11-28",
#     "fecha_inicio_sintomas": "2019-06-05",
#     "edad": 15,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 887312941",
#     "celular": "092507998",
#     "prestador": "Supermercados Gimenez S.L.",
#     "internado": "N",
#     "tipo_internado": "sin dato",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 37,
#     "Plaquetas (/mm3)": 486873,
#     "Leucocitos sangre (/mm3)": 28151,
#     "Función hepática BT (mg/dl)": 13.8,
#     "Función hepática TGO (UI/l)": 59.8,
#     "Función hepática LDH (mg/dl)": 640,
#     "Función hepática TGP (UI/l)": 18.5,
#     "Función renal azoemia (mg/dl)": 42.4,
#     "Función renal creatinemia (mg/dl)": 1.0,
#     "AE": 2019,
#     "SE": 23,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "639-30-2536",
#         "nombre": "Chucho",
#         "apellido": "Vega",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-06-10",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Encarnita",
#     "apellido": "Infante",
#     "direccion": "Vial Hermenegildo Rozas 11",
#     "localidad": "León",
#     "departamento": "Santa Cruz de Tenerife",
#     "latitud": -7.1364305,
#     "longitud": 138.472065,
#     "cedula": "758-96-1890",
#     "fecha_nacimiento": "2004-11-17",
#     "fecha_inicio_sintomas": "2019-10-06",
#     "edad": 16,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34901 78 47 17",
#     "celular": "093711995",
#     "prestador": "Pellicer y Olivera S.Com.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 43,
#     "Plaquetas (/mm3)": 880279,
#     "Leucocitos sangre (/mm3)": 11075,
#     "Función hepática BT (mg/dl)": 11.0,
#     "Función hepática TGO (UI/l)": 56.0,
#     "Función hepática LDH (mg/dl)": 926,
#     "Función hepática TGP (UI/l)": 97.0,
#     "Función renal azoemia (mg/dl)": 40.5,
#     "Función renal creatinemia (mg/dl)": 3.3,
#     "AE": 2019,
#     "SE": 40,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "206-65-0187",
#         "nombre": "Reinaldo",
#         "apellido": "Arregui",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-10-11",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Vidal",
#     "apellido": "Gallego",
#     "direccion": "Callejón Josep Juan 74",
#     "localidad": "Guadalajara",
#     "departamento": "Teruel",
#     "latitud": 82.1621005,
#     "longitud": 38.296591,
#     "cedula": "817-84-2173",
#     "fecha_nacimiento": "1991-09-23",
#     "fecha_inicio_sintomas": "2019-03-20",
#     "edad": 49,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34974267601",
#     "celular": "091307394",
#     "prestador": "Baquero & Asociados S.L.",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 32,
#     "Plaquetas (/mm3)": 562180,
#     "Leucocitos sangre (/mm3)": 15395,
#     "Función hepática BT (mg/dl)": 19.1,
#     "Función hepática TGO (UI/l)": 69.0,
#     "Función hepática LDH (mg/dl)": 326,
#     "Función hepática TGP (UI/l)": 27.9,
#     "Función renal azoemia (mg/dl)": 96.2,
#     "Función renal creatinemia (mg/dl)": 4.3,
#     "AE": 2019,
#     "SE": 12,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "427-77-4286",
#         "nombre": "Jose Antonio",
#         "apellido": "Ricart",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-03-25",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Narcisa",
#     "apellido": "Royo",
#     "direccion": "Via Isabel Sanchez 96",
#     "localidad": "Girona",
#     "departamento": "Vizcaya",
#     "latitud": 4.79934,
#     "longitud": -115.542779,
#     "cedula": "125-65-7417",
#     "fecha_nacimiento": "2023-01-22",
#     "fecha_inicio_sintomas": "2019-07-11",
#     "edad": 82,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34849217462",
#     "celular": "095059839",
#     "prestador": "Grupo Heras S.Com.",
#     "internado": "N",
#     "tipo_internado": "CM",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 30,
#     "Plaquetas (/mm3)": 936880,
#     "Leucocitos sangre (/mm3)": 13639,
#     "Función hepática BT (mg/dl)": 7.6,
#     "Función hepática TGO (UI/l)": 64.5,
#     "Función hepática LDH (mg/dl)": 443,
#     "Función hepática TGP (UI/l)": 82.2,
#     "Función renal azoemia (mg/dl)": 84.6,
#     "Función renal creatinemia (mg/dl)": 9.5,
#     "AE": 2019,
#     "SE": 28,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "206-05-7017",
#         "nombre": "Sabas",
#         "apellido": "Pombo",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-07-16",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Maximiliano",
#     "apellido": "Lozano",
#     "direccion": "C. de Héctor Baños 58",
#     "localidad": "Castellón",
#     "departamento": "Baleares",
#     "latitud": -52.163065,
#     "longitud": -117.351879,
#     "cedula": "151-80-3177",
#     "fecha_nacimiento": "1949-03-08",
#     "fecha_inicio_sintomas": "2019-04-29",
#     "edad": 10,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 883017106",
#     "celular": "096642653",
#     "prestador": "Comercial Inteligentes S.L.",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 42,
#     "Plaquetas (/mm3)": 285561,
#     "Leucocitos sangre (/mm3)": 17302,
#     "Función hepática BT (mg/dl)": 10.6,
#     "Función hepática TGO (UI/l)": 70.1,
#     "Función hepática LDH (mg/dl)": 512,
#     "Función hepática TGP (UI/l)": 92.8,
#     "Función renal azoemia (mg/dl)": 50.1,
#     "Función renal creatinemia (mg/dl)": 2.7,
#     "AE": 2019,
#     "SE": 18,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "918-54-7652",
#         "nombre": "Amílcar",
#         "apellido": "Lozano",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-05-04",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Anna",
#     "apellido": "Julián",
#     "direccion": "Avenida de Chus Verdejo 13",
#     "localidad": "Santa Cruz de Tenerife",
#     "departamento": "Albacete",
#     "latitud": 68.830136,
#     "longitud": 19.508104,
#     "cedula": "750-32-9388",
#     "fecha_nacimiento": "1963-04-24",
#     "fecha_inicio_sintomas": "2019-04-02",
#     "edad": 29,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 850 80 44 67",
#     "celular": "098724375",
#     "prestador": "Hotel VYCC S.Coop.",
#     "internado": "S",
#     "tipo_internado": "CTI",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 43,
#     "Plaquetas (/mm3)": 483612,
#     "Leucocitos sangre (/mm3)": 25947,
#     "Función hepática BT (mg/dl)": 8.2,
#     "Función hepática TGO (UI/l)": 20.1,
#     "Función hepática LDH (mg/dl)": 261,
#     "Función hepática TGP (UI/l)": 83.7,
#     "Función renal azoemia (mg/dl)": 87.6,
#     "Función renal creatinemia (mg/dl)": 8.1,
#     "AE": 2019,
#     "SE": 14,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "344-04-6708",
#         "nombre": "Rosaura",
#         "apellido": "Sánchez",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2019-04-07",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Casandra",
#     "apellido": "Ávila",
#     "direccion": "Alameda de Severino Casals 73",
#     "localidad": "Castellón",
#     "departamento": "Santa Cruz de Tenerife",
#     "latitud": -68.218953,
#     "longitud": -147.802891,
#     "cedula": "259-41-2394",
#     "fecha_nacimiento": "1961-09-06",
#     "fecha_inicio_sintomas": "2019-11-13",
#     "edad": 5,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34871 91 39 88",
#     "celular": "097675188",
#     "prestador": "Cervera y Guillén S.L.",
#     "internado": "S",
#     "tipo_internado": "CTI",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "S",
# ...
#         "nombre": "Hilda",
#         "apellido": "Albero",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-05-19",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Valentina",
#     "apellido": "Miguel",
#     "direccion": "Ronda de Esmeralda Revilla 14",
#     "localidad": "Teruel",
#     "departamento": "Cantabria",
#     "latitud": 42.791056,
#     "longitud": 101.742551,
#     "cedula": "092-88-1747",
#     "fecha_nacimiento": "1964-08-22",
#     "fecha_inicio_sintomas": "2023-03-17",
#     "edad": 50,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34 924484948",
#     "celular": "091181926",
#     "prestador": "Instalaciones López S.L.N.E",
#     "internado": "S",
#     "tipo_internado": "CM",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 50,
#     "Plaquetas (/mm3)": 145647,
#     "Leucocitos sangre (/mm3)": 28749,
#     "Función hepática BT (mg/dl)": 17.1,
#     "Función hepática TGO (UI/l)": 22.3,
#     "Función hepática LDH (mg/dl)": 508,
#     "Función hepática TGP (UI/l)": 97.7,
#     "Función renal azoemia (mg/dl)": 48.8,
#     "Función renal creatinemia (mg/dl)": 2.5,
#     "AE": 2023,
#     "SE": 11,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "591-19-2926",
#         "nombre": "Severino",
#         "apellido": "Aguirre",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-03-22",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Josefa",
#     "apellido": "Cuéllar",
#     "direccion": "C. María Fernanda Zabala 24",
#     "localidad": "Sevilla",
#     "departamento": "Guadalajara",
#     "latitud": 13.9040875,
#     "longitud": -148.203545,
#     "cedula": "269-79-6409",
#     "fecha_nacimiento": "1970-02-01",
#     "fecha_inicio_sintomas": "2023-02-27",
#     "edad": 84,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34986292393",
#     "celular": "092771723",
#     "prestador": "Alcalde y Aliaga S.Com.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 31,
#     "Plaquetas (/mm3)": 659911,
#     "Leucocitos sangre (/mm3)": 10293,
#     "Función hepática BT (mg/dl)": 8.4,
#     "Función hepática TGO (UI/l)": 78.6,
#     "Función hepática LDH (mg/dl)": 494,
#     "Función hepática TGP (UI/l)": 91.6,
#     "Función renal azoemia (mg/dl)": 38.3,
#     "Función renal creatinemia (mg/dl)": 2.0,
#     "AE": 2023,
#     "SE": 9,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "612-47-0412",
#         "nombre": "Caridad",
#         "apellido": "Galván",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-03-04",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Ciríaco",
#     "apellido": "Mendez",
#     "direccion": "Paseo de Felicia Benavente 10",
#     "localidad": "Cantabria",
#     "departamento": "Valencia",
#     "latitud": 43.5258865,
#     "longitud": -54.494219,
#     "cedula": "544-06-7939",
#     "fecha_nacimiento": "1971-04-05",
#     "fecha_inicio_sintomas": "2023-08-19",
#     "edad": 65,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34 885940126",
#     "celular": "095537146",
#     "prestador": "Grupo Río S.A.",
#     "internado": "N",
#     "tipo_internado": "CTI",
#     "Fiebre": "S",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 35,
#     "Plaquetas (/mm3)": 127964,
#     "Leucocitos sangre (/mm3)": 24563,
#     "Función hepática BT (mg/dl)": 4.6,
#     "Función hepática TGO (UI/l)": 55.6,
#     "Función hepática LDH (mg/dl)": 729,
#     "Función hepática TGP (UI/l)": 53.4,
#     "Función renal azoemia (mg/dl)": 34.7,
#     "Función renal creatinemia (mg/dl)": 2.6,
#     "AE": 2023,
#     "SE": 34,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "946-66-5285",
#         "nombre": "Soledad",
#         "apellido": "Expósito",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-08-24",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Juanito",
#     "apellido": "Gallo",
#     "direccion": "C. de Toño Carranza 56",
#     "localidad": "La Coruña",
#     "departamento": "Ávila",
#     "latitud": -46.0950625,
#     "longitud": -43.05477,
#     "cedula": "032-86-1533",
#     "fecha_nacimiento": "2012-03-09",
#     "fecha_inicio_sintomas": "2023-05-03",
#     "edad": 2,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34 873 267 217",
#     "celular": "097597110",
#     "prestador": "Tecnologías Reyes S.Com.",
#     "internado": "N",
#     "tipo_internado": "CM",
#     "Fiebre": "S",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 48,
#     "Plaquetas (/mm3)": 165172,
#     "Leucocitos sangre (/mm3)": 11259,
#     "Función hepática BT (mg/dl)": 14.9,
#     "Función hepática TGO (UI/l)": 71.6,
#     "Función hepática LDH (mg/dl)": 748,
#     "Función hepática TGP (UI/l)": 14.1,
#     "Función renal azoemia (mg/dl)": 15.3,
#     "Función renal creatinemia (mg/dl)": 8.5,
#     "AE": 2023,
#     "SE": 18,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "074-72-0134",
#         "nombre": "Poncio",
#         "apellido": "Zapata",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-05-08",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Goyo",
#     "apellido": "Ramón",
#     "direccion": "Calle Geraldo Aramburu 27",
#     "localidad": "Valladolid",
#     "departamento": "Santa Cruz de Tenerife",
#     "latitud": 40.718099,
#     "longitud": 76.122359,
#     "cedula": "148-34-9855",
#     "fecha_nacimiento": "1945-08-05",
#     "fecha_inicio_sintomas": "2023-01-29",
#     "edad": 17,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34910 11 60 98",
#     "celular": "098198385",
#     "prestador": "Barbero y Frías S.A.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "S",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 43,
#     "Plaquetas (/mm3)": 159047,
#     "Leucocitos sangre (/mm3)": 27014,
#     "Función hepática BT (mg/dl)": 14.4,
#     "Función hepática TGO (UI/l)": 79.8,
#     "Función hepática LDH (mg/dl)": 913,
#     "Función hepática TGP (UI/l)": 49.5,
#     "Función renal azoemia (mg/dl)": 62.4,
#     "Función renal creatinemia (mg/dl)": 8.8,
#     "AE": 2023,
#     "SE": 5,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "566-76-0282",
#         "nombre": "Melchor",
#         "apellido": "Escrivá",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-02-03",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Viviana",
#     "apellido": "Varela",
#     "direccion": "Urbanización de Miguel Ángel Malo 87",
#     "localidad": "Málaga",
#     "departamento": "Guadalajara",
#     "latitud": -43.8823225,
#     "longitud": -94.695687,
#     "cedula": "684-50-6577",
#     "fecha_nacimiento": "2005-06-20",
#     "fecha_inicio_sintomas": "2023-11-23",
#     "edad": 48,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34923 253 342",
#     "celular": "097533895",
#     "prestador": "Construcción Arranz y asociados S.Com.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "S",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "S",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 47,
#     "Plaquetas (/mm3)": 818428,
#     "Leucocitos sangre (/mm3)": 14152,
#     "Función hepática BT (mg/dl)": 8.4,
#     "Función hepática TGO (UI/l)": 85.2,
#     "Función hepática LDH (mg/dl)": 422,
#     "Función hepática TGP (UI/l)": 52.0,
#     "Función renal azoemia (mg/dl)": 94.1,
#     "Función renal creatinemia (mg/dl)": 0.8,
#     "AE": 2023,
#     "SE": 47,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "029-14-9726",
#         "nombre": "Fito",
#         "apellido": "Ríos",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-11-28",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Artemio",
#     "apellido": "Adadia",
#     "direccion": "Callejón de Curro Noguera 79",
#     "localidad": "Toledo",
#     "departamento": "Zamora",
#     "latitud": -68.218734,
#     "longitud": 17.257931,
#     "cedula": "424-56-4369",
#     "fecha_nacimiento": "1949-10-05",
#     "fecha_inicio_sintomas": "2023-12-01",
#     "edad": 80,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34821 65 12 38",
#     "celular": "095050798",
#     "prestador": "Carlos y Haro S.L.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "N",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 43,
#     "Plaquetas (/mm3)": 727826,
#     "Leucocitos sangre (/mm3)": 19571,
#     "Función hepática BT (mg/dl)": 17.7,
#     "Función hepática TGO (UI/l)": 79.1,
#     "Función hepática LDH (mg/dl)": 702,
#     "Función hepática TGP (UI/l)": 28.6,
#     "Función renal azoemia (mg/dl)": 92.1,
#     "Función renal creatinemia (mg/dl)": 9.0,
#     "AE": 2023,
#     "SE": 48,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "214-44-0808",
#         "nombre": "Germán",
#         "apellido": "Cepeda",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-12-06",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Cloe",
#     "apellido": "Tena",
#     "direccion": "Via de Borja Pazos 47",
#     "localidad": "Valladolid",
#     "departamento": "Melilla",
#     "latitud": -24.692199,
#     "longitud": -104.834376,
#     "cedula": "802-57-2103",
#     "fecha_nacimiento": "2011-02-22",
#     "fecha_inicio_sintomas": "2023-09-22",
#     "edad": 79,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34 972884260",
#     "celular": "092629668",
#     "prestador": "Minería Alcaraz y asociados S.A.",
#     "internado": "N",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "S",
#     "Compromiso hepático": "N",
#     "Sintomatología digestiva": "S",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 31,
#     "Plaquetas (/mm3)": 461240,
#     "Leucocitos sangre (/mm3)": 16264,
#     "Función hepática BT (mg/dl)": 16.6,
#     "Función hepática TGO (UI/l)": 23.2,
#     "Función hepática LDH (mg/dl)": 542,
#     "Función hepática TGP (UI/l)": 73.4,
#     "Función renal azoemia (mg/dl)": 47.9,
#     "Función renal creatinemia (mg/dl)": 5.7,
#     "AE": 2023,
#     "SE": 38,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "544-87-2600",
#         "nombre": "Ulises",
#         "apellido": "Carreras",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-09-27",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Nerea",
#     "apellido": "Barrena",
#     "direccion": "Callejón de Amanda Arenas 52",
#     "localidad": "Cáceres",
#     "departamento": "León",
#     "latitud": 31.8867135,
#     "longitud": -161.504975,
#     "cedula": "720-64-0251",
#     "fecha_nacimiento": "1994-01-06",
#     "fecha_inicio_sintomas": "2023-09-23",
#     "edad": 29,
#     "sexo": "F",
#     "evento": "Leptospirosis",
#     "telefono": "+34843134859",
#     "celular": "091995741",
#     "prestador": "Promociones Ibéricos S.A.",
#     "internado": "S",
#     "tipo_internado": "sin dato",
#     "Fiebre": "N",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "S",
#     "Mialgias y/o artralgias": "N",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "S",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "N",
#     "Hematocrito (%)": 43,
#     "Plaquetas (/mm3)": 926021,
#     "Leucocitos sangre (/mm3)": 13528,
#     "Función hepática BT (mg/dl)": 9.5,
#     "Función hepática TGO (UI/l)": 16.2,
#     "Función hepática LDH (mg/dl)": 550,
#     "Función hepática TGP (UI/l)": 44.5,
#     "Función renal azoemia (mg/dl)": 39.6,
#     "Función renal creatinemia (mg/dl)": 6.9,
#     "AE": 2023,
#     "SE": 39,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "151-21-9740",
#         "nombre": "Anselma",
#         "apellido": "Armas",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-09-28",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }
# {
#     "nombre": "Florinda",
#     "apellido": "Uría",
#     "direccion": "Cuesta de Fátima Iborra 29",
#     "localidad": "Las Palmas",
#     "departamento": "Las Palmas",
#     "latitud": 4.045155,
#     "longitud": 162.507391,
#     "cedula": "949-03-2285",
#     "fecha_nacimiento": "1958-12-03",
#     "fecha_inicio_sintomas": "2023-10-28",
#     "edad": 73,
#     "sexo": "M",
#     "evento": "Leptospirosis",
#     "telefono": "+34880546223",
#     "celular": "099273773",
#     "prestador": "Hnos Arjona S.L.U.",
#     "internado": "N",
#     "tipo_internado": "CM",
#     "Fiebre": "S",
#     "Cefalea": "N",
#     "Síndrome hemorragíparo": "N",
#     "Mialgias y/o artralgias": "S",
#     "Compromiso renal": "N",
#     "Compromiso hepático": "S",
#     "Sintomatología digestiva": "N",
#     "Ictericia": "N",
#     "Hiperemia conjuntival": "S",
#     "Neumonia/Neumonitis": "N",
#     "Lesiones de piel": "S",
#     "Hematocrito (%)": 48,
#     "Plaquetas (/mm3)": 285420,
#     "Leucocitos sangre (/mm3)": 29919,
#     "Función hepática BT (mg/dl)": 15.5,
#     "Función hepática TGO (UI/l)": 59.1,
#     "Función hepática LDH (mg/dl)": 362,
#     "Función hepática TGP (UI/l)": 36.2,
#     "Función renal azoemia (mg/dl)": 82.9,
#     "Función renal creatinemia (mg/dl)": 7.2,
#     "AE": 2023,
#     "SE": 44,
#     "estado": "confirmado",
#     "resultados_laboratorio": {
#         "cedula": "180-48-1948",
#         "nombre": "Luciano",
#         "apellido": "Girón",
#         "evento": "Leptospirosis",
#         "fecha_muestra": "2023-11-02",
#         "estado": "finalizado",
#         "test": "PCR",
#         "resultado": "positivo"
#     }
# }

# %%
import json
from collections import Counter

# Ruta al archivo JSON
archivo_json = 'leptospirosis_data.json'

# Cargar el archivo JSON
with open(archivo_json, 'r', encoding='utf-8') as archivo:
    datos = json.load(archivo)

# Contar los casos por AE
contar_ae = Counter(registro.get('AE') for registro in datos)

# Mostrar el conteo por AE
for ae, conteo in contar_ae.items():
    print(f"Año Epidemiológico {ae}: {conteo} casos")
# Out:
# Año Epidemiológico 2019: 125 casos
# Año Epidemiológico 2020: 130 casos
# Año Epidemiológico 2021: 122 casos
# Año Epidemiológico 2022: 113 casos
# Año Epidemiológico 2023: 130 casos

# %%
import json
from collections import defaultdict

# Cargar los datos desde el archivo JSON
with open('leptospirosis_data.json', 'r', encoding='utf-8') as file:
    data = json.load(file)

# Inicializar un diccionario para contar los casos por SE
casos_por_se = defaultdict(int)

# Procesar los datos
for caso in data:
    if caso['AE'] == 2019:  # Filtrar solo los casos del año 2019
        se = caso['SE']
        casos_por_se[se] += 1  # Contar el caso para la semana epidemiológica correspondiente

# Convertir el resultado en una lista de diccionarios para facilitar la visualización
casos_por_se_list = [{'SE': se, 'cantidad_casos': count} for se, count in casos_por_se.items()]

# Mostrar los resultados
for entry in casos_por_se_list:
    print(f"Semana Epidemiológica {entry['SE']}: {entry['cantidad_casos']} casos")

# Guardar los resultados en un archivo JSON
with open('casos_por_se_2019.json', 'w', encoding='utf-8') as file:
    json.dump(casos_por_se_list, file, ensure_ascii=False, indent=4)
# Out:
# Semana Epidemiológica 34: 4 casos
# Semana Epidemiológica 33: 1 casos
# Semana Epidemiológica 31: 4 casos
# Semana Epidemiológica 15: 2 casos
# Semana Epidemiológica 37: 2 casos
# Semana Epidemiológica 45: 1 casos
# Semana Epidemiológica 32: 4 casos
# Semana Epidemiológica 38: 2 casos
# Semana Epidemiológica 42: 2 casos
# Semana Epidemiológica 26: 3 casos
# Semana Epidemiológica 35: 1 casos
# Semana Epidemiológica 22: 4 casos
# Semana Epidemiológica 1: 6 casos
# Semana Epidemiológica 3: 4 casos
# Semana Epidemiológica 51: 1 casos
# Semana Epidemiológica 46: 5 casos
# Semana Epidemiológica 52: 1 casos
# Semana Epidemiológica 29: 4 casos
# Semana Epidemiológica 36: 2 casos
# Semana Epidemiológica 23: 3 casos
# Semana Epidemiológica 40: 5 casos
# Semana Epidemiológica 12: 2 casos
# Semana Epidemiológica 28: 2 casos
# Semana Epidemiológica 18: 3 casos
# Semana Epidemiológica 14: 2 casos
# Semana Epidemiológica 11: 5 casos
# Semana Epidemiológica 25: 5 casos
# Semana Epidemiológica 19: 2 casos
# Semana Epidemiológica 2: 1 casos
# Semana Epidemiológica 41: 2 casos
# Semana Epidemiológica 10: 2 casos
# Semana Epidemiológica 4: 6 casos
# Semana Epidemiológica 17: 4 casos
# Semana Epidemiológica 43: 2 casos
# Semana Epidemiológica 27: 2 casos
# Semana Epidemiológica 24: 2 casos
# Semana Epidemiológica 7: 1 casos
# Semana Epidemiológica 20: 4 casos
# Semana Epidemiológica 44: 1 casos
# Semana Epidemiológica 50: 2 casos
# Semana Epidemiológica 39: 2 casos
# Semana Epidemiológica 9: 2 casos
# Semana Epidemiológica 8: 1 casos
# Semana Epidemiológica 21: 1 casos
# Semana Epidemiológica 47: 1 casos
# Semana Epidemiológica 13: 1 casos
# Semana Epidemiológica 16: 1 casos
# Semana Epidemiológica 49: 1 casos
# Semana Epidemiológica 30: 1 casos
# Semana Epidemiológica 5: 2 casos
# Semana Epidemiológica 6: 1 casos
